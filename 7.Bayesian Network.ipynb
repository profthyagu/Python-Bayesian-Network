# %% [markdown]
# # 7.Problem : Write a program to construct a Bayesian network considering medical data. Use this model to demonstrate the diagnosis of heart patients using standard Heart Disease Data Set. You can use Python ML library API.

# %% [markdown]
# References:  http://pgmpy.org/  and https://www.inertia7.com/projects/55

# %% [markdown]
# # 7.1. Constructing  a Bayesian Network considering Medical Data

# %% [markdown]
# # 7.1.1 Defining a Structure with nodes and edges

# %%
# Author : Dr.Thyagaraju G S , Context Innovations Lab , DEpt of CSE , SDMIT - Ujire 
# Date : July 11 2018 
# Starting with defining the network structure
from pgmpy.models import BayesianModel

cancer_model = BayesianModel([('Pollution', 'Cancer'), 
                              ('Smoker', 'Cancer'),
                              ('Cancer', 'Xray'),
                              ('Cancer', 'Dyspnoea')])

# %%
print(cancer_model)

# %%
cancer_model.nodes()
# Out:
# ['Pollution', 'Cancer', 'Smoker', 'Xray', 'Dyspnoea']

# %%
cancer_model.edges()
# Out:
# [('Pollution', 'Cancer'),
#  ('Cancer', 'Xray'),
#  ('Cancer', 'Dyspnoea'),
#  ('Smoker', 'Cancer')]

# %%
cancer_model.get_cpds()
# Out:
# []

# %% [markdown]
# # 7.1.2 Creation  of Conditional Probability Table

# %%
# Now defining the parameters.
from pgmpy.factors.discrete import TabularCPD

cpd_poll = TabularCPD(variable='Pollution', variable_card=2,
                      values=[[0.9], [0.1]])
cpd_smoke = TabularCPD(variable='Smoker', variable_card=2,
                       values=[[0.3], [0.7]])
cpd_cancer = TabularCPD(variable='Cancer', variable_card=2,
                        values=[[0.03, 0.05, 0.001, 0.02],
                                [0.97, 0.95, 0.999, 0.98]],
                        evidence=['Smoker', 'Pollution'],
                        evidence_card=[2, 2])
cpd_xray = TabularCPD(variable='Xray', variable_card=2,
                      values=[[0.9, 0.2], [0.1, 0.8]],
                      evidence=['Cancer'], evidence_card=[2])
cpd_dysp = TabularCPD(variable='Dyspnoea', variable_card=2,
                      values=[[0.65, 0.3], [0.35, 0.7]],
                      evidence=['Cancer'], evidence_card=[2])

# %% [markdown]
# # 7.1.3 Associating Conditional probabilities with the Bayesian Structure

# %%
# Associating the parameters with the model structure.
cancer_model.add_cpds(cpd_poll, cpd_smoke, cpd_cancer, cpd_xray, cpd_dysp)

# Checking if the cpds are valid for the model.
cancer_model.check_model()
# Out:
# True

# %%
# Doing some simple queries on the network
cancer_model.is_active_trail('Pollution', 'Smoker')
# Out:
# False

# %%
cancer_model.is_active_trail('Pollution', 'Smoker', observed=['Cancer'])
# Out:
# True

# %%
cancer_model.get_cpds()
# Out:
# [<TabularCPD representing P(Pollution:2) at 0x84ca390>,
#  <TabularCPD representing P(Smoker:2) at 0x84ca3b0>,
#  <TabularCPD representing P(Cancer:2 | Smoker:2, Pollution:2) at 0x84ca3d0>,
#  <TabularCPD representing P(Xray:2 | Cancer:2) at 0x84ca430>,
#  <TabularCPD representing P(Dyspnoea:2 | Cancer:2) at 0x84ca410>]

# %%
print(cancer_model.get_cpds('Pollution'))
# Out:
# ╒═════════════╤═════╕
# │ Pollution_0 │ 0.9 │
# ├─────────────┼─────┤
# │ Pollution_1 │ 0.1 │
# ╘═════════════╧═════╛

# %%
print(cancer_model.get_cpds('Smoker'))
# Out:
# ╒══════════╤═════╕
# │ Smoker_0 │ 0.3 │
# ├──────────┼─────┤
# │ Smoker_1 │ 0.7 │
# ╘══════════╧═════╛

# %%
print(cancer_model.get_cpds('Xray'))
# Out:
# ╒════════╤══════════╤══════════╕
# │ Cancer │ Cancer_0 │ Cancer_1 │
# ├────────┼──────────┼──────────┤
# │ Xray_0 │ 0.9      │ 0.2      │
# ├────────┼──────────┼──────────┤
# │ Xray_1 │ 0.1      │ 0.8      │
# ╘════════╧══════════╧══════════╛

# %%
print(cancer_model.get_cpds('Dyspnoea'))
# Out:
# ╒════════════╤══════════╤══════════╕
# │ Cancer     │ Cancer_0 │ Cancer_1 │
# ├────────────┼──────────┼──────────┤
# │ Dyspnoea_0 │ 0.65     │ 0.3      │
# ├────────────┼──────────┼──────────┤
# │ Dyspnoea_1 │ 0.35     │ 0.7      │
# ╘════════════╧══════════╧══════════╛

# %%
print(cancer_model.get_cpds('Cancer'))
# Out:
# ╒═══════════╤═════════════╤═════════════╤═════════════╤═════════════╕
# │ Smoker    │ Smoker_0    │ Smoker_0    │ Smoker_1    │ Smoker_1    │
# ├───────────┼─────────────┼─────────────┼─────────────┼─────────────┤
# │ Pollution │ Pollution_0 │ Pollution_1 │ Pollution_0 │ Pollution_1 │
# ├───────────┼─────────────┼─────────────┼─────────────┼─────────────┤
# │ Cancer_0  │ 0.03        │ 0.05        │ 0.001       │ 0.02        │
# ├───────────┼─────────────┼─────────────┼─────────────┼─────────────┤
# │ Cancer_1  │ 0.97        │ 0.95        │ 0.999       │ 0.98        │
# ╘═══════════╧═════════════╧═════════════╧═════════════╧═════════════╛

# %% [markdown]
# # 7.1.4 Determining the Local independencies

# %%
cancer_model.local_independencies('Xray')
# Out:
# (Xray _|_ Dyspnoea, Pollution, Smoker | Cancer)

# %%
cancer_model.local_independencies('Pollution')
# Out:
# (Pollution _|_ Smoker)

# %%
cancer_model.local_independencies('Smoker')
# Out:
# (Smoker _|_ Pollution)

# %%
cancer_model.local_independencies('Dyspnoea')
# Out:
# (Dyspnoea _|_ Pollution, Xray, Smoker | Cancer)

# %%
cancer_model.local_independencies('Cancer')

# %%
cancer_model.get_independencies()
# Out:
# (Pollution _|_ Smoker)
# (Pollution _|_ Dyspnoea, Xray | Cancer)
# (Pollution _|_ Xray | Dyspnoea, Cancer)
# (Pollution _|_ Dyspnoea, Xray | Cancer, Smoker)
# (Pollution _|_ Dyspnoea | Cancer, Xray)
# (Pollution _|_ Xray | Dyspnoea, Cancer, Smoker)
# (Pollution _|_ Dyspnoea | Cancer, Xray, Smoker)
# (Smoker _|_ Pollution)
# (Smoker _|_ Dyspnoea, Xray | Cancer)
# (Smoker _|_ Xray | Dyspnoea, Cancer)
# (Smoker _|_ Dyspnoea, Xray | Cancer, Pollution)
# (Smoker _|_ Dyspnoea | Cancer, Xray)
# (Smoker _|_ Xray | Dyspnoea, Cancer, Pollution)
# (Smoker _|_ Dyspnoea | Cancer, Pollution, Xray)
# (Xray _|_ Dyspnoea, Pollution, Smoker | Cancer)
# (Xray _|_ Pollution, Smoker | Dyspnoea, Cancer)
# (Xray _|_ Dyspnoea, Smoker | Cancer, Pollution)
# (Xray _|_ Dyspnoea, Pollution | Cancer, Smoker)
# (Xray _|_ Smoker | Dyspnoea, Cancer, Pollution)
# (Xray _|_ Pollution | Dyspnoea, Cancer, Smoker)
# (Xray _|_ Dyspnoea | Cancer, Pollution, Smoker)
# (Dyspnoea _|_ Pollution, Smoker, Xray | Cancer)
# (Dyspnoea _|_ Smoker, Xray | Cancer, Pollution)
# (Dyspnoea _|_ Pollution, Xray | Cancer, Smoker)
# (Dyspnoea _|_ Pollution, Smoker | Cancer, Xray)
# (Dyspnoea _|_ Xray | Cancer, Pollution, Smoker)
# (Dyspnoea _|_ Smoker | Cancer, Pollution, Xray)
# (Dyspnoea _|_ Pollution | Cancer, Xray, Smoker)

# %% [markdown]
# # 7.1.5.Inferencing with Bayesian Network

# %%
# Doing exact inference using Variable Elimination
from pgmpy.inference import VariableElimination
cancer_infer = VariableElimination(cancer_model)

# Computing the probability of bronc given smoke.
q = cancer_infer.query(variables=['Cancer'], evidence={'Smoker': 1})
print(q['Cancer'])
# Out:
# ╒══════════╤═══════════════╕
# │ Cancer   │   phi(Cancer) │
# ╞══════════╪═══════════════╡
# │ Cancer_0 │        0.0029 │
# ├──────────┼───────────────┤
# │ Cancer_1 │        0.9971 │
# ╘══════════╧═══════════════╛

# %%
# Computing the probability of bronc given smoke.
q = cancer_infer.query(variables=['Cancer'], evidence={'Smoker': 1})
print(q['Cancer'])
# Out:
# ╒══════════╤═══════════════╕
# │ Cancer   │   phi(Cancer) │
# ╞══════════╪═══════════════╡
# │ Cancer_0 │        0.0029 │
# ├──────────┼───────────────┤
# │ Cancer_1 │        0.9971 │
# ╘══════════╧═══════════════╛

# %%
# Computing the probability of bronc given smoke.
q = cancer_infer.query(variables=['Cancer'], evidence={'Smoker': 1,'Pollution': 1})
print(q['Cancer'])
# Out:
# ╒══════════╤═══════════════╕
# │ Cancer   │   phi(Cancer) │
# ╞══════════╪═══════════════╡
# │ Cancer_0 │        0.0200 │
# ├──────────┼───────────────┤
# │ Cancer_1 │        0.9800 │
# ╘══════════╧═══════════════╛

# %% [markdown]
# # 7.2 Diagnosis of heart patients using standard Heart Disease Data Set

# %%
import numpy as np
from urllib.request import urlopen
import urllib
import matplotlib.pyplot as plt # Visuals
import seaborn as sns 
import sklearn as skl
import pandas as pd

# %% [markdown]
# # 7.2.1 Importing Heart Disease Data Set and Customizing

# %%
Cleveland_data_URL = 'http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.hungarian.data'
#Hungarian_data_URL = 'http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.hungarian.data'
#Switzerland_data_URL = 'http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.switzerland.data'
np.set_printoptions(threshold=np.nan) #see a whole array when we output it

names = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'heartdisease']
heartDisease = pd.read_csv(urlopen(Cleveland_data_URL), names = names) #gets Cleveland data
#HungarianHeartDisease = pd.read_csv(urlopen(Hungarian_data_URL), names = names) #gets Hungary data
#SwitzerlandHeartDisease = pd.read_csv(urlopen(Switzerland_data_URL), names = names) #gets Switzerland data
#datatemp = [ClevelandHeartDisease, HungarianHeartDisease, SwitzerlandHeartDisease] #combines all arrays into a list
#heartDisease = pd.concat(datatemp)#combines list into one array
heartDisease.head()
# Out:
#    age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak slope ca  \
# 0   28    1   2      130  132   0       2     185     0      0.0     ?  ?
# 1   29    1   2      120  243   0       0     160     0      0.0     ?  ?
# 2   29    1   2      140    ?   0       0     170     0      0.0     ?  ?
# 3   30    0   1      170  237   0       1     170     0      0.0     ?  ?
# 4   31    0   2      100  219   0       1     150     0      0.0     ?  ?
#
#   thal  heartdisease
# 0    ?             0
# 1    ?             0
# 2    ?             0
# 3    6             0
# 4    ?             0

# %%
del heartDisease['ca']
del heartDisease['slope']
del heartDisease['thal']
del heartDisease['oldpeak']

heartDisease = heartDisease.replace('?', np.nan)
heartDisease.dtypes
# Out:
# age              int64
# sex              int64
# cp               int64
# trestbps        object
# chol            object
# fbs             object
# restecg         object
# thalach         object
# exang           object
# heartdisease     int64
# dtype: object

# %%
heartDisease.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'heartdisease'],
#       dtype='object')

# %% [markdown]
# # 7.2.2 Modeling Heart Disease Data

# %%
from pgmpy.models import BayesianModel
from pgmpy.estimators import MaximumLikelihoodEstimator, BayesianEstimator

model = BayesianModel([('age', 'trestbps'), ('age', 'fbs'), ('sex', 'trestbps'), ('sex', 'trestbps'), 
                       ('exang', 'trestbps'),('trestbps','heartdisease'),('fbs','heartdisease'),
                      ('heartdisease','restecg'),('heartdisease','thalach'),('heartdisease','chol')])

# Learing CPDs using Maximum Likelihood Estimators
model.fit(heartDisease, estimator=MaximumLikelihoodEstimator)
#for cpd in model.get_cpds():
 #   print("CPD of {variable}:".format(variable=cpd.variable))
  #  print(cpd)

# %%
print(model.get_cpds('age'))
# Out:
# ╒═════════╤════════════╕
# │ age(28) │ 0.00383142 │
# ├─────────┼────────────┤
# │ age(29) │ 0.00383142 │
# ├─────────┼────────────┤
# │ age(30) │ 0.00383142 │
# ├─────────┼────────────┤
# │ age(31) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(32) │ 0.0153257  │
# ├─────────┼────────────┤
# │ age(33) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(34) │ 0.0153257  │
# ├─────────┼────────────┤
# │ age(35) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(36) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(37) │ 0.0306513  │
# ├─────────┼────────────┤
# │ age(38) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(39) │ 0.0344828  │
# ├─────────┼────────────┤
# │ age(40) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(41) │ 0.0383142  │
# ├─────────┼────────────┤
# │ age(42) │ 0.0268199  │
# ├─────────┼────────────┤
# │ age(43) │ 0.0421456  │
# ├─────────┼────────────┤
# │ age(44) │ 0.0268199  │
# ├─────────┼────────────┤
# │ age(45) │ 0.0229885  │
# ├─────────┼────────────┤
# │ age(46) │ 0.045977   │
# ├─────────┼────────────┤
# │ age(47) │ 0.0344828  │
# ├─────────┼────────────┤
# │ age(48) │ 0.0613027  │
# ├─────────┼────────────┤
# │ age(49) │ 0.0421456  │
# ├─────────┼────────────┤
# │ age(50) │ 0.045977   │
# ├─────────┼────────────┤
# │ age(51) │ 0.0344828  │
# ├─────────┼────────────┤
# │ age(52) │ 0.0574713  │
# ├─────────┼────────────┤
# │ age(53) │ 0.0383142  │
# ├─────────┼────────────┤
# │ age(54) │ 0.0842912  │
# ├─────────┼────────────┤
# │ age(55) │ 0.0536398  │
# ├─────────┼────────────┤
# │ age(56) │ 0.0306513  │
# ├─────────┼────────────┤
# │ age(57) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(58) │ 0.0344828  │
# ├─────────┼────────────┤
# │ age(59) │ 0.0229885  │
# ├─────────┼────────────┤
# │ age(60) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(61) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(62) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(63) │ 0.00383142 │
# ├─────────┼────────────┤
# │ age(65) │ 0.0114943  │
# ├─────────┼────────────┤
# │ age(66) │ 0          │
# ╘═════════╧════════════╛

# %%
print(model.get_cpds('chol'))
# Out:
# ╒══════════════╤══════════════════════╤══════════════════════╕
# │ heartdisease │ heartdisease(0)      │ heartdisease(1)      │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(100)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(117)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(129)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(132)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(147)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(156)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(160)    │ 0.012269938650306749 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(161)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(163)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(164)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(166)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(167)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(168)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(171)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(172)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(173)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(175)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(179)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(180)    │ 0.006134969325153374 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(182)    │ 0.012269938650306749 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(184)    │ 0.018404907975460124 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(186)    │ 0.006134969325153374 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(187)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(188)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(190)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(193)    │ 0.006134969325153374 │ 0.02040816326530612  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(194)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(195)    │ 0.018404907975460124 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(196)    │ 0.018404907975460124 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(198)    │ 0.012269938650306749 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(200)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(201)    │ 0.012269938650306749 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(202)    │ 0.006134969325153374 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(204)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(205)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(206)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(207)    │ 0.012269938650306749 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(208)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(209)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(210)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(211)    │ 0.018404907975460124 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(212)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(213)    │ 0.006134969325153374 │ 0.02040816326530612  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(214)    │ 0.006134969325153374 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(215)    │ 0.024539877300613498 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(216)    │ 0.012269938650306749 │ 0.02040816326530612  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(217)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(218)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(219)    │ 0.006134969325153374 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(220)    │ 0.018404907975460124 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(221)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(222)    │ 0.006134969325153374 │ 0.02040816326530612  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(223)    │ 0.012269938650306749 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(224)    │ 0.018404907975460124 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(225)    │ 0.012269938650306749 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(226)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(227)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(228)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(229)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(230)    │ 0.024539877300613498 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(231)    │ 0.0                  │ 0.02040816326530612  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(233)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(234)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(237)    │ 0.012269938650306749 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(238)    │ 0.024539877300613498 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(240)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(241)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(242)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(243)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(245)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(246)    │ 0.012269938650306749 │ 0.030612244897959183 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(247)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(248)    │ 0.0                  │ 0.030612244897959183 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(249)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(250)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(251)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(253)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(254)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(255)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(256)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(257)    │ 0.006134969325153374 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(259)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(260)    │ 0.018404907975460124 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(263)    │ 0.006134969325153374 │ 0.030612244897959183 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(264)    │ 0.006134969325153374 │ 0.02040816326530612  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(265)    │ 0.0                  │ 0.02040816326530612  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(266)    │ 0.006134969325153374 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(267)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(268)    │ 0.006134969325153374 │ 0.02040816326530612  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(269)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(270)    │ 0.006134969325153374 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(271)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(272)    │ 0.006134969325153374 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(273)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(274)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(275)    │ 0.012269938650306749 │ 0.02040816326530612  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(276)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(277)    │ 0.006134969325153374 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(279)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(280)    │ 0.006134969325153374 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(281)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(282)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(283)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(284)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(285)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(287)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(288)    │ 0.0                  │ 0.030612244897959183 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(289)    │ 0.006134969325153374 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(290)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(291)    │ 0.006134969325153374 │ 0.02040816326530612  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(292)    │ 0.012269938650306749 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(294)    │ 0.006134969325153374 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(295)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(297)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(298)    │ 0.006134969325153374 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(303)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(305)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(306)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(307)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(308)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(309)    │ 0.0                  │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(312)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(315)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(318)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(320)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(326)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(328)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(329)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(331)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(336)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(338)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(339)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(340)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(341)    │ 0.0                  │ 0.02040816326530612  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(342)    │ 0.0                  │ 0.02040816326530612  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(344)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(347)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(355)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(358)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(365)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(388)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(392)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(393)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(394)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(404)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(412)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(466)    │ 0.0                  │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(468)    │ 0.0                  │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(491)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(518)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(529)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(603)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(85)     │ 0.006134969325153374 │ 0.0                  │
# ╘══════════════╧══════════════════════╧══════════════════════╛

# %%
print(model.get_cpds('sex'))
# Out:
# ╒════════╤══════════╕
# │ sex(0) │ 0.264368 │
# ├────────┼──────────┤
# │ sex(1) │ 0.735632 │
# ╘════════╧══════════╛

# %%
model.get_independencies()
# Out:
# (age _|_ exang, sex)
# (age _|_ sex | exang)
# (age _|_ exang, sex | fbs)
# (age _|_ thalach, chol, restecg | heartdisease)
# (age _|_ exang | sex)
# (age _|_ thalach, restecg | chol, heartdisease)
# (age _|_ thalach, chol, heartdisease, restecg | trestbps, fbs)
# (age _|_ thalach, chol, restecg | trestbps, heartdisease)
# (age _|_ chol, restecg | thalach, heartdisease)
# (age _|_ sex | exang, fbs)
# (age _|_ thalach, chol, restecg | exang, heartdisease)
# (age _|_ thalach, chol, restecg | fbs, heartdisease)
# (age _|_ exang | fbs, sex)
# (age _|_ thalach, chol, restecg | heartdisease, sex)
# (age _|_ thalach, chol | heartdisease, restecg)
# (age _|_ thalach, heartdisease, restecg | trestbps, chol, fbs)
# (age _|_ thalach, restecg | trestbps, chol, heartdisease)
# (age _|_ restecg | thalach, chol, heartdisease)
# (age _|_ thalach, restecg | exang, chol, heartdisease)
# (age _|_ thalach, restecg | fbs, chol, heartdisease)
# (age _|_ thalach, restecg | chol, heartdisease, sex)
# (age _|_ thalach | chol, heartdisease, restecg)
# (age _|_ chol, heartdisease, restecg | trestbps, thalach, fbs)
# (age _|_ chol, restecg | trestbps, thalach, heartdisease)
# (age _|_ thalach, chol, heartdisease, restecg | trestbps, fbs, exang)
# (age _|_ thalach, chol, restecg | trestbps, heartdisease, exang)
# (age _|_ thalach, chol, restecg | trestbps, fbs, heartdisease)
# (age _|_ thalach, chol, heartdisease, restecg | trestbps, fbs, sex)
# (age _|_ thalach, chol, heartdisease | trestbps, fbs, restecg)
# (age _|_ thalach, chol, restecg | trestbps, heartdisease, sex)
# (age _|_ thalach, chol | trestbps, heartdisease, restecg)
# (age _|_ chol, restecg | thalach, heartdisease, exang)
# (age _|_ chol, restecg | thalach, fbs, heartdisease)
# (age _|_ chol, restecg | thalach, heartdisease, sex)
# (age _|_ chol | thalach, heartdisease, restecg)
# (age _|_ thalach, chol, restecg | exang, fbs, heartdisease)
# (age _|_ thalach, chol, restecg | exang, heartdisease, sex)
# (age _|_ thalach, chol | exang, heartdisease, restecg)
# (age _|_ thalach, chol, restecg | fbs, heartdisease, sex)
# (age _|_ thalach, chol | fbs, heartdisease, restecg)
# (age _|_ thalach, chol | heartdisease, restecg, sex)
# (age _|_ heartdisease, restecg | trestbps, chol, thalach, fbs)
# (age _|_ restecg | trestbps, chol, heartdisease, thalach)
# (age _|_ thalach, heartdisease, restecg | trestbps, chol, exang, fbs)
# (age _|_ thalach, restecg | trestbps, chol, heartdisease, exang)
# (age _|_ thalach, restecg | trestbps, chol, heartdisease, fbs)
# (age _|_ thalach, heartdisease, restecg | trestbps, chol, sex, fbs)
# (age _|_ thalach, heartdisease | trestbps, chol, restecg, fbs)
# (age _|_ thalach, restecg | trestbps, chol, heartdisease, sex)
# (age _|_ thalach | trestbps, chol, heartdisease, restecg)
# (age _|_ restecg | thalach, chol, heartdisease, exang)
# (age _|_ restecg | thalach, chol, heartdisease, fbs)
# (age _|_ restecg | thalach, chol, heartdisease, sex)
# (age _|_ thalach, restecg | exang, chol, heartdisease, fbs)
# (age _|_ thalach, restecg | exang, chol, heartdisease, sex)
# (age _|_ thalach | exang, chol, heartdisease, restecg)
# (age _|_ thalach, restecg | fbs, chol, heartdisease, sex)
# (age _|_ thalach | fbs, chol, heartdisease, restecg)
# (age _|_ thalach | chol, heartdisease, sex, restecg)
# (age _|_ chol, heartdisease, restecg | trestbps, thalach, exang, fbs)
# (age _|_ chol, restecg | trestbps, thalach, heartdisease, exang)
# (age _|_ chol, restecg | trestbps, thalach, heartdisease, fbs)
# (age _|_ chol, heartdisease, restecg | trestbps, thalach, sex, fbs)
# (age _|_ chol, heartdisease | trestbps, thalach, restecg, fbs)
# (age _|_ chol, restecg | trestbps, thalach, heartdisease, sex)
# (age _|_ chol | trestbps, thalach, heartdisease, restecg)
# (age _|_ thalach, chol, restecg | trestbps, fbs, heartdisease, exang)
# (age _|_ thalach, chol, heartdisease, restecg | trestbps, fbs, sex, exang)
# (age _|_ thalach, chol, heartdisease | trestbps, fbs, restecg, exang)
# (age _|_ thalach, chol, restecg | trestbps, heartdisease, sex, exang)
# (age _|_ thalach, chol | trestbps, heartdisease, restecg, exang)
# (age _|_ thalach, chol, restecg | trestbps, fbs, heartdisease, sex)
# (age _|_ thalach, chol | trestbps, fbs, heartdisease, restecg)
# (age _|_ thalach, chol, heartdisease | trestbps, fbs, restecg, sex)
# (age _|_ thalach, chol | trestbps, heartdisease, restecg, sex)
# (age _|_ chol, restecg | thalach, fbs, heartdisease, exang)
# (age _|_ chol, restecg | thalach, heartdisease, sex, exang)
# (age _|_ chol | thalach, heartdisease, restecg, exang)
# (age _|_ chol, restecg | thalach, fbs, heartdisease, sex)
# (age _|_ chol | thalach, fbs, heartdisease, restecg)
# (age _|_ chol | thalach, heartdisease, restecg, sex)
# (age _|_ thalach, chol, restecg | exang, fbs, heartdisease, sex)
# (age _|_ thalach, chol | exang, fbs, heartdisease, restecg)
# (age _|_ thalach, chol | exang, heartdisease, restecg, sex)
# (age _|_ thalach, chol | fbs, heartdisease, sex, restecg)
# (age _|_ heartdisease, restecg | chol, trestbps, thalach, exang, fbs)
# (age _|_ restecg | chol, trestbps, thalach, exang, heartdisease)
# (age _|_ restecg | fbs, chol, trestbps, thalach, heartdisease)
# (age _|_ heartdisease, restecg | fbs, chol, trestbps, thalach, sex)
# (age _|_ heartdisease | chol, trestbps, thalach, fbs, restecg)
# (age _|_ restecg | chol, trestbps, thalach, heartdisease, sex)
# (age _|_ thalach, restecg | fbs, chol, trestbps, exang, heartdisease)
# (age _|_ thalach, heartdisease, restecg | fbs, chol, trestbps, exang, sex)
# (age _|_ thalach, heartdisease | chol, trestbps, exang, fbs, restecg)
# (age _|_ thalach, restecg | chol, trestbps, exang, heartdisease, sex)
# (age _|_ thalach | chol, trestbps, exang, heartdisease, restecg)
# (age _|_ thalach, restecg | fbs, chol, trestbps, heartdisease, sex)
# (age _|_ thalach | fbs, chol, trestbps, heartdisease, restecg)
# (age _|_ thalach, heartdisease | fbs, chol, trestbps, sex, restecg)
# (age _|_ thalach | chol, trestbps, heartdisease, restecg, sex)
# (age _|_ restecg | fbs, chol, thalach, exang, heartdisease)
# (age _|_ restecg | chol, thalach, exang, heartdisease, sex)
# (age _|_ restecg | fbs, chol, thalach, heartdisease, sex)
# (age _|_ thalach, restecg | fbs, chol, exang, heartdisease, sex)
# (age _|_ thalach | fbs, chol, exang, heartdisease, restecg)
# (age _|_ thalach | chol, exang, heartdisease, restecg, sex)
# (age _|_ thalach | chol, fbs, heartdisease, sex, restecg)
# (age _|_ chol, restecg | fbs, trestbps, thalach, exang, heartdisease)
# (age _|_ chol, heartdisease, restecg | fbs, trestbps, thalach, exang, sex)
# (age _|_ chol, heartdisease | trestbps, thalach, exang, fbs, restecg)
# (age _|_ chol, restecg | trestbps, thalach, exang, heartdisease, sex)
# (age _|_ chol | trestbps, thalach, exang, heartdisease, restecg)
# (age _|_ chol, restecg | fbs, trestbps, thalach, heartdisease, sex)
# (age _|_ chol | fbs, trestbps, thalach, heartdisease, restecg)
# (age _|_ chol, heartdisease | fbs, trestbps, thalach, sex, restecg)
# (age _|_ chol | trestbps, thalach, heartdisease, restecg, sex)
# (age _|_ thalach, chol, restecg | trestbps, exang, fbs, heartdisease, sex)
# (age _|_ thalach, chol | trestbps, exang, fbs, heartdisease, restecg)
# (age _|_ thalach, chol, heartdisease | trestbps, exang, fbs, restecg, sex)
# (age _|_ thalach, chol | trestbps, exang, heartdisease, restecg, sex)
# (age _|_ thalach, chol | trestbps, fbs, heartdisease, sex, restecg)
# (age _|_ chol, restecg | thalach, exang, fbs, heartdisease, sex)
# (age _|_ chol | thalach, exang, fbs, heartdisease, restecg)
# (age _|_ chol | thalach, exang, heartdisease, restecg, sex)
# (age _|_ chol | thalach, fbs, heartdisease, sex, restecg)
# (age _|_ thalach, chol | exang, fbs, heartdisease, sex, restecg)
# (age _|_ restecg | chol, trestbps, thalach, exang, fbs, heartdisease)
# (age _|_ heartdisease, restecg | chol, trestbps, thalach, exang, fbs, sex)
# (age _|_ heartdisease | chol, trestbps, thalach, exang, fbs, restecg)
# (age _|_ restecg | chol, trestbps, thalach, exang, heartdisease, sex)
# (age _|_ restecg | fbs, chol, trestbps, thalach, heartdisease, sex)
# (age _|_ heartdisease | fbs, chol, trestbps, thalach, sex, restecg)
# (age _|_ thalach, restecg | fbs, chol, trestbps, exang, heartdisease, sex)
# (age _|_ thalach | fbs, chol, trestbps, exang, heartdisease, restecg)
# (age _|_ thalach, heartdisease | fbs, chol, trestbps, exang, sex, restecg)
# (age _|_ thalach | chol, trestbps, exang, heartdisease, restecg, sex)
# (age _|_ thalach | fbs, chol, trestbps, heartdisease, restecg, sex)
# (age _|_ restecg | fbs, chol, thalach, exang, heartdisease, sex)
# (age _|_ thalach | fbs, chol, exang, heartdisease, restecg, sex)
# (age _|_ chol, restecg | fbs, trestbps, thalach, exang, heartdisease, sex)
# (age _|_ chol | fbs, trestbps, thalach, exang, heartdisease, restecg)
# (age _|_ chol, heartdisease | fbs, trestbps, thalach, exang, sex, restecg)
# (age _|_ chol | trestbps, thalach, exang, heartdisease, restecg, sex)
# (age _|_ chol | fbs, trestbps, thalach, heartdisease, restecg, sex)
# (age _|_ thalach, chol | trestbps, exang, fbs, heartdisease, sex, restecg)
# (age _|_ chol | thalach, exang, fbs, heartdisease, sex, restecg)
# (age _|_ restecg | chol, trestbps, thalach, exang, fbs, heartdisease, sex)
# (age _|_ heartdisease | chol, trestbps, thalach, exang, fbs, restecg, sex)
# (age _|_ thalach | fbs, chol, trestbps, exang, heartdisease, restecg, sex)
# (age _|_ chol | fbs, trestbps, thalach, exang, heartdisease, restecg, sex)
# (trestbps _|_ fbs | age)
# (trestbps _|_ thalach, chol, restecg | heartdisease)
# (trestbps _|_ thalach, restecg | chol, heartdisease)
# (trestbps _|_ chol, restecg | thalach, heartdisease)
# (trestbps _|_ fbs | exang, age)
# (trestbps _|_ thalach, chol, restecg | heartdisease, age)
# (trestbps _|_ fbs | sex, age)
# (trestbps _|_ thalach, chol, restecg | exang, heartdisease)
# (trestbps _|_ thalach, chol, restecg | fbs, heartdisease)
# (trestbps _|_ thalach, chol, restecg | heartdisease, sex)
# (trestbps _|_ thalach, chol | heartdisease, restecg)
# (trestbps _|_ restecg | thalach, chol, heartdisease)
# (trestbps _|_ thalach, restecg | chol, heartdisease, age)
# (trestbps _|_ thalach, restecg | exang, chol, heartdisease)
# (trestbps _|_ thalach, restecg | fbs, chol, heartdisease)
# (trestbps _|_ thalach, restecg | chol, heartdisease, sex)
# (trestbps _|_ thalach | chol, heartdisease, restecg)
# (trestbps _|_ chol, restecg | thalach, heartdisease, age)
# (trestbps _|_ chol, restecg | thalach, heartdisease, exang)
# (trestbps _|_ chol, restecg | thalach, fbs, heartdisease)
# (trestbps _|_ chol, restecg | thalach, heartdisease, sex)
# (trestbps _|_ chol | thalach, heartdisease, restecg)
# (trestbps _|_ thalach, chol, restecg | exang, heartdisease, age)
# (trestbps _|_ fbs | exang, sex, age)
# (trestbps _|_ thalach, chol, restecg | fbs, heartdisease, age)
# (trestbps _|_ thalach, chol, restecg | heartdisease, sex, age)
# (trestbps _|_ thalach, chol | heartdisease, restecg, age)
# (trestbps _|_ thalach, chol, restecg | exang, fbs, heartdisease)
# (trestbps _|_ thalach, chol, restecg | exang, heartdisease, sex)
# (trestbps _|_ thalach, chol | exang, heartdisease, restecg)
# (trestbps _|_ thalach, chol, restecg | fbs, heartdisease, sex)
# (trestbps _|_ thalach, chol | fbs, heartdisease, restecg)
# (trestbps _|_ thalach, chol | heartdisease, restecg, sex)
# (trestbps _|_ restecg | thalach, chol, heartdisease, age)
# (trestbps _|_ restecg | thalach, chol, heartdisease, exang)
# (trestbps _|_ restecg | thalach, chol, heartdisease, fbs)
# (trestbps _|_ restecg | thalach, chol, heartdisease, sex)
# (trestbps _|_ thalach, restecg | exang, chol, heartdisease, age)
# (trestbps _|_ thalach, restecg | fbs, chol, heartdisease, age)
# (trestbps _|_ thalach, restecg | chol, heartdisease, sex, age)
# (trestbps _|_ thalach | chol, heartdisease, age, restecg)
# (trestbps _|_ thalach, restecg | exang, chol, heartdisease, fbs)
# (trestbps _|_ thalach, restecg | exang, chol, heartdisease, sex)
# (trestbps _|_ thalach | exang, chol, heartdisease, restecg)
# (trestbps _|_ thalach, restecg | fbs, chol, heartdisease, sex)
# (trestbps _|_ thalach | fbs, chol, heartdisease, restecg)
# (trestbps _|_ thalach | chol, heartdisease, sex, restecg)
# (trestbps _|_ chol, restecg | thalach, heartdisease, exang, age)
# (trestbps _|_ chol, restecg | thalach, fbs, heartdisease, age)
# (trestbps _|_ chol, restecg | thalach, heartdisease, sex, age)
# (trestbps _|_ chol | thalach, heartdisease, restecg, age)
# (trestbps _|_ chol, restecg | thalach, fbs, heartdisease, exang)
# (trestbps _|_ chol, restecg | thalach, heartdisease, sex, exang)
# (trestbps _|_ chol | thalach, heartdisease, restecg, exang)
# (trestbps _|_ chol, restecg | thalach, fbs, heartdisease, sex)
# (trestbps _|_ chol | thalach, fbs, heartdisease, restecg)
# (trestbps _|_ chol | thalach, heartdisease, restecg, sex)
# (trestbps _|_ thalach, chol, restecg | exang, fbs, heartdisease, age)
# (trestbps _|_ thalach, chol, restecg | exang, heartdisease, sex, age)
# (trestbps _|_ thalach, chol | exang, heartdisease, restecg, age)
# (trestbps _|_ thalach, chol, restecg | fbs, heartdisease, sex, age)
# (trestbps _|_ thalach, chol | fbs, heartdisease, age, restecg)
# (trestbps _|_ thalach, chol | heartdisease, restecg, sex, age)
# (trestbps _|_ thalach, chol, restecg | exang, fbs, heartdisease, sex)
# (trestbps _|_ thalach, chol | exang, fbs, heartdisease, restecg)
# (trestbps _|_ thalach, chol | exang, heartdisease, restecg, sex)
# (trestbps _|_ thalach, chol | fbs, heartdisease, sex, restecg)
# (trestbps _|_ restecg | chol, thalach, age, exang, heartdisease)
# (trestbps _|_ restecg | fbs, chol, thalach, age, heartdisease)
# (trestbps _|_ restecg | chol, thalach, age, heartdisease, sex)
# (trestbps _|_ restecg | fbs, chol, thalach, exang, heartdisease)
# (trestbps _|_ restecg | chol, thalach, exang, heartdisease, sex)
# (trestbps _|_ restecg | fbs, chol, thalach, heartdisease, sex)
# (trestbps _|_ thalach, restecg | fbs, chol, age, exang, heartdisease)
# (trestbps _|_ thalach, restecg | chol, age, exang, heartdisease, sex)
# (trestbps _|_ thalach | chol, age, exang, heartdisease, restecg)
# (trestbps _|_ thalach, restecg | chol, age, fbs, heartdisease, sex)
# (trestbps _|_ thalach | chol, age, fbs, heartdisease, restecg)
# (trestbps _|_ thalach | chol, age, heartdisease, restecg, sex)
# (trestbps _|_ thalach, restecg | fbs, chol, exang, heartdisease, sex)
# (trestbps _|_ thalach | fbs, chol, exang, heartdisease, restecg)
# (trestbps _|_ thalach | chol, exang, heartdisease, restecg, sex)
# (trestbps _|_ thalach | chol, fbs, heartdisease, sex, restecg)
# (trestbps _|_ chol, restecg | thalach, age, exang, fbs, heartdisease)
# (trestbps _|_ chol, restecg | thalach, age, exang, heartdisease, sex)
# (trestbps _|_ chol | thalach, age, exang, heartdisease, restecg)
# (trestbps _|_ chol, restecg | thalach, age, fbs, heartdisease, sex)
# (trestbps _|_ chol | thalach, age, fbs, heartdisease, restecg)
# (trestbps _|_ chol | thalach, age, heartdisease, restecg, sex)
# (trestbps _|_ chol, restecg | thalach, exang, fbs, heartdisease, sex)
# (trestbps _|_ chol | thalach, exang, fbs, heartdisease, restecg)
# (trestbps _|_ chol | thalach, exang, heartdisease, restecg, sex)
# (trestbps _|_ chol | thalach, fbs, heartdisease, sex, restecg)
# (trestbps _|_ thalach, chol, restecg | age, exang, fbs, heartdisease, sex)
# (trestbps _|_ thalach, chol | age, exang, fbs, heartdisease, restecg)
# (trestbps _|_ thalach, chol | age, exang, heartdisease, restecg, sex)
# (trestbps _|_ thalach, chol | age, fbs, heartdisease, sex, restecg)
# (trestbps _|_ thalach, chol | exang, fbs, heartdisease, sex, restecg)
# (trestbps _|_ restecg | chol, thalach, age, exang, fbs, heartdisease)
# (trestbps _|_ restecg | chol, thalach, age, exang, heartdisease, sex)
# (trestbps _|_ restecg | fbs, chol, thalach, age, heartdisease, sex)
# (trestbps _|_ restecg | fbs, chol, thalach, exang, heartdisease, sex)
# (trestbps _|_ thalach, restecg | fbs, chol, age, exang, heartdisease, sex)
# (trestbps _|_ thalach | fbs, chol, age, exang, heartdisease, restecg)
# (trestbps _|_ thalach | chol, age, exang, heartdisease, restecg, sex)
# (trestbps _|_ thalach | chol, age, fbs, heartdisease, sex, restecg)
# (trestbps _|_ thalach | fbs, chol, exang, heartdisease, restecg, sex)
# (trestbps _|_ chol, restecg | thalach, age, exang, fbs, heartdisease, sex)
# (trestbps _|_ chol | thalach, age, exang, fbs, heartdisease, restecg)
# (trestbps _|_ chol | thalach, age, exang, heartdisease, restecg, sex)
# (trestbps _|_ chol | thalach, age, fbs, heartdisease, sex, restecg)
# (trestbps _|_ chol | thalach, exang, fbs, heartdisease, sex, restecg)
# (trestbps _|_ thalach, chol | age, exang, fbs, heartdisease, sex, restecg)
# (trestbps _|_ restecg | chol, thalach, age, exang, fbs, heartdisease, sex)
# (trestbps _|_ thalach | fbs, chol, age, exang, heartdisease, restecg, sex)
# (trestbps _|_ chol | thalach, age, exang, fbs, heartdisease, sex, restecg)
# (fbs _|_ exang, sex)
# (fbs _|_ trestbps, sex, exang | age)
# (fbs _|_ sex | exang)
# (fbs _|_ thalach, chol, restecg | heartdisease)
# (fbs _|_ exang | sex)
# (fbs _|_ thalach, restecg | chol, heartdisease)
# (fbs _|_ exang, sex | trestbps, age)
# (fbs _|_ thalach, chol, restecg | trestbps, heartdisease)
# (fbs _|_ chol, restecg | thalach, heartdisease)
# (fbs _|_ trestbps, sex | exang, age)
# (fbs _|_ thalach, chol, restecg | heartdisease, age)
# (fbs _|_ trestbps, exang | sex, age)
# (fbs _|_ thalach, chol, restecg | exang, heartdisease)
# (fbs _|_ thalach, chol, restecg | heartdisease, sex)
# (fbs _|_ thalach, chol | heartdisease, restecg)
# (fbs _|_ exang, sex | trestbps, chol, age)
# (fbs _|_ thalach, restecg | trestbps, chol, heartdisease)
# (fbs _|_ restecg | thalach, chol, heartdisease)
# (fbs _|_ thalach, restecg | chol, heartdisease, age)
# (fbs _|_ thalach, restecg | exang, chol, heartdisease)
# (fbs _|_ thalach, restecg | chol, heartdisease, sex)
# (fbs _|_ thalach | chol, heartdisease, restecg)
# (fbs _|_ exang, sex | trestbps, thalach, age)
# (fbs _|_ chol, restecg | trestbps, thalach, heartdisease)
# (fbs _|_ sex | trestbps, exang, age)
# (fbs _|_ thalach, exang, chol, restecg, sex | trestbps, heartdisease, age)
# (fbs _|_ exang | trestbps, sex, age)
# (fbs _|_ exang, sex | trestbps, restecg, age)
# (fbs _|_ thalach, chol, restecg | trestbps, heartdisease, exang)
# (fbs _|_ thalach, chol, restecg | trestbps, heartdisease, sex)
# (fbs _|_ thalach, chol | trestbps, heartdisease, restecg)
# (fbs _|_ chol, restecg | thalach, heartdisease, age)
# (fbs _|_ chol, restecg | thalach, heartdisease, exang)
# (fbs _|_ chol, restecg | thalach, heartdisease, sex)
# (fbs _|_ chol | thalach, heartdisease, restecg)
# (fbs _|_ thalach, chol, restecg | exang, heartdisease, age)
# (fbs _|_ trestbps | exang, sex, age)
# (fbs _|_ thalach, chol, restecg | heartdisease, sex, age)
# (fbs _|_ thalach, chol | heartdisease, restecg, age)
# (fbs _|_ thalach, chol, restecg | exang, heartdisease, sex)
# (fbs _|_ thalach, chol | exang, heartdisease, restecg)
# (fbs _|_ thalach, chol | heartdisease, restecg, sex)
# (fbs _|_ exang, sex | trestbps, chol, thalach, age)
# (fbs _|_ restecg | trestbps, chol, heartdisease, thalach)
# (fbs _|_ sex | trestbps, chol, exang, age)
# (fbs _|_ thalach, sex, restecg, exang | trestbps, chol, heartdisease, age)
# (fbs _|_ exang | trestbps, chol, sex, age)
# (fbs _|_ exang, sex | trestbps, chol, restecg, age)
# (fbs _|_ thalach, restecg | trestbps, chol, heartdisease, exang)
# (fbs _|_ thalach, restecg | trestbps, chol, heartdisease, sex)
# (fbs _|_ thalach | trestbps, chol, heartdisease, restecg)
# (fbs _|_ restecg | thalach, chol, heartdisease, age)
# (fbs _|_ restecg | thalach, chol, heartdisease, exang)
# (fbs _|_ restecg | thalach, chol, heartdisease, sex)
# (fbs _|_ thalach, restecg | exang, chol, heartdisease, age)
# (fbs _|_ thalach, restecg | chol, heartdisease, sex, age)
# (fbs _|_ thalach | chol, heartdisease, age, restecg)
# (fbs _|_ thalach, restecg | exang, chol, heartdisease, sex)
# (fbs _|_ thalach | exang, chol, heartdisease, restecg)
# (fbs _|_ thalach | chol, heartdisease, sex, restecg)
# (fbs _|_ sex | trestbps, thalach, exang, age)
# (fbs _|_ exang, chol, restecg, sex | trestbps, thalach, heartdisease, age)
# (fbs _|_ exang | trestbps, thalach, sex, age)
# (fbs _|_ exang, sex | trestbps, thalach, restecg, age)
# (fbs _|_ chol, restecg | trestbps, thalach, heartdisease, exang)
# (fbs _|_ chol, restecg | trestbps, thalach, heartdisease, sex)
# (fbs _|_ chol | trestbps, thalach, heartdisease, restecg)
# (fbs _|_ thalach, chol, restecg, sex | trestbps, heartdisease, exang, age)
# (fbs _|_ sex | trestbps, restecg, exang, age)
# (fbs _|_ thalach, chol, restecg, exang | trestbps, heartdisease, sex, age)
# (fbs _|_ thalach, chol, sex, exang | trestbps, heartdisease, restecg, age)
# (fbs _|_ exang | trestbps, sex, restecg, age)
# (fbs _|_ thalach, chol, restecg | trestbps, heartdisease, sex, exang)
# (fbs _|_ thalach, chol | trestbps, heartdisease, restecg, exang)
# (fbs _|_ thalach, chol | trestbps, heartdisease, restecg, sex)
# (fbs _|_ chol, restecg | thalach, heartdisease, exang, age)
# (fbs _|_ chol, restecg | thalach, heartdisease, sex, age)
# (fbs _|_ chol | thalach, heartdisease, restecg, age)
# (fbs _|_ chol, restecg | thalach, heartdisease, sex, exang)
# (fbs _|_ chol | thalach, heartdisease, restecg, exang)
# (fbs _|_ chol | thalach, heartdisease, restecg, sex)
# (fbs _|_ thalach, chol, restecg | exang, heartdisease, sex, age)
# (fbs _|_ thalach, chol | exang, heartdisease, restecg, age)
# (fbs _|_ thalach, chol | heartdisease, restecg, sex, age)
# (fbs _|_ thalach, chol | exang, heartdisease, restecg, sex)
# (fbs _|_ sex | chol, trestbps, thalach, age, exang)
# (fbs _|_ exang, sex, restecg | chol, trestbps, thalach, age, heartdisease)
# (fbs _|_ exang | chol, trestbps, thalach, age, sex)
# (fbs _|_ exang, sex | chol, trestbps, thalach, age, restecg)
# (fbs _|_ restecg | chol, trestbps, thalach, exang, heartdisease)
# (fbs _|_ restecg | chol, trestbps, thalach, heartdisease, sex)
# (fbs _|_ thalach, sex, restecg | chol, trestbps, age, exang, heartdisease)
# (fbs _|_ sex | chol, trestbps, age, exang, restecg)
# (fbs _|_ thalach, restecg, exang | chol, trestbps, age, heartdisease, sex)
# (fbs _|_ thalach, sex, exang | chol, trestbps, age, heartdisease, restecg)
# (fbs _|_ exang | chol, trestbps, age, sex, restecg)
# (fbs _|_ thalach, restecg | chol, trestbps, exang, heartdisease, sex)
# (fbs _|_ thalach | chol, trestbps, exang, heartdisease, restecg)
# (fbs _|_ thalach | chol, trestbps, heartdisease, restecg, sex)
# (fbs _|_ restecg | chol, thalach, age, exang, heartdisease)
# (fbs _|_ restecg | chol, thalach, age, heartdisease, sex)
# (fbs _|_ restecg | chol, thalach, exang, heartdisease, sex)
# (fbs _|_ thalach, restecg | chol, age, exang, heartdisease, sex)
# (fbs _|_ thalach | chol, age, exang, heartdisease, restecg)
# (fbs _|_ thalach | chol, age, heartdisease, restecg, sex)
# (fbs _|_ thalach | chol, exang, heartdisease, restecg, sex)
# (fbs _|_ chol, restecg, sex | trestbps, thalach, age, exang, heartdisease)
# (fbs _|_ sex | trestbps, thalach, age, exang, restecg)
# (fbs _|_ exang, chol, restecg | trestbps, thalach, age, heartdisease, sex)
# (fbs _|_ exang, chol, sex | trestbps, thalach, age, heartdisease, restecg)
# (fbs _|_ exang | trestbps, thalach, age, sex, restecg)
# (fbs _|_ chol, restecg | trestbps, thalach, exang, heartdisease, sex)
# (fbs _|_ chol | trestbps, thalach, exang, heartdisease, restecg)
# (fbs _|_ chol | trestbps, thalach, heartdisease, restecg, sex)
# (fbs _|_ thalach, chol, restecg | trestbps, age, exang, heartdisease, sex)
# (fbs _|_ thalach, chol, sex | trestbps, age, exang, heartdisease, restecg)
# (fbs _|_ thalach, chol, exang | trestbps, age, heartdisease, restecg, sex)
# (fbs _|_ thalach, chol | trestbps, exang, heartdisease, restecg, sex)
# (fbs _|_ chol, restecg | thalach, age, exang, heartdisease, sex)
# (fbs _|_ chol | thalach, age, exang, heartdisease, restecg)
# (fbs _|_ chol | thalach, age, heartdisease, restecg, sex)
# (fbs _|_ chol | thalach, exang, heartdisease, restecg, sex)
# (fbs _|_ thalach, chol | age, exang, heartdisease, restecg, sex)
# (fbs _|_ sex, restecg | chol, trestbps, thalach, age, exang, heartdisease)
# (fbs _|_ sex | chol, trestbps, thalach, age, exang, restecg)
# (fbs _|_ exang, restecg | chol, trestbps, thalach, age, heartdisease, sex)
# (fbs _|_ exang, sex | chol, trestbps, thalach, age, heartdisease, restecg)
# (fbs _|_ exang | chol, trestbps, thalach, age, sex, restecg)
# (fbs _|_ restecg | chol, trestbps, thalach, exang, heartdisease, sex)
# (fbs _|_ thalach, restecg | chol, trestbps, age, exang, heartdisease, sex)
# (fbs _|_ thalach, sex | chol, trestbps, age, exang, heartdisease, restecg)
# (fbs _|_ thalach, exang | chol, trestbps, age, heartdisease, restecg, sex)
# (fbs _|_ thalach | chol, trestbps, exang, heartdisease, restecg, sex)
# (fbs _|_ restecg | chol, thalach, age, exang, heartdisease, sex)
# (fbs _|_ thalach | chol, age, exang, heartdisease, restecg, sex)
# (fbs _|_ chol, restecg | trestbps, thalach, age, exang, heartdisease, sex)
# (fbs _|_ chol, sex | trestbps, thalach, age, exang, heartdisease, restecg)
# (fbs _|_ exang, chol | trestbps, thalach, age, heartdisease, restecg, sex)
# (fbs _|_ chol | trestbps, thalach, exang, heartdisease, restecg, sex)
# (fbs _|_ thalach, chol | trestbps, age, exang, heartdisease, restecg, sex)
# (fbs _|_ chol | thalach, age, exang, heartdisease, restecg, sex)
# (fbs _|_ restecg | chol, trestbps, thalach, age, exang, heartdisease, sex)
# (fbs _|_ sex | chol, trestbps, thalach, age, exang, heartdisease, restecg)
# (fbs _|_ exang | chol, trestbps, thalach, age, heartdisease, restecg, sex)
# (fbs _|_ thalach | chol, trestbps, age, exang, heartdisease, restecg, sex)
# (fbs _|_ chol | trestbps, thalach, age, exang, heartdisease, restecg, sex)
# (sex _|_ exang, fbs, age)
# (sex _|_ exang, fbs | age)
# (sex _|_ fbs, age | exang)
# (sex _|_ exang, age | fbs)
# (sex _|_ thalach, chol, restecg | heartdisease)
# (sex _|_ thalach, restecg | chol, heartdisease)
# (sex _|_ thalach, fbs, chol, heartdisease, restecg | trestbps, age)
# (sex _|_ thalach, chol, heartdisease, restecg | trestbps, fbs)
# (sex _|_ thalach, chol, restecg | trestbps, heartdisease)
# (sex _|_ chol, restecg | thalach, heartdisease)
# (sex _|_ fbs | exang, age)
# (sex _|_ exang | fbs, age)
# (sex _|_ thalach, chol, restecg | heartdisease, age)
# (sex _|_ age | exang, fbs)
# (sex _|_ thalach, chol, restecg | exang, heartdisease)
# (sex _|_ thalach, chol, restecg | fbs, heartdisease)
# (sex _|_ thalach, chol | heartdisease, restecg)
# (sex _|_ thalach, fbs, heartdisease, restecg | trestbps, chol, age)
# (sex _|_ thalach, heartdisease, restecg | trestbps, chol, fbs)
# (sex _|_ thalach, restecg | trestbps, chol, heartdisease)
# (sex _|_ restecg | thalach, chol, heartdisease)
# (sex _|_ thalach, restecg | chol, heartdisease, age)
# (sex _|_ thalach, restecg | exang, chol, heartdisease)
# (sex _|_ thalach, restecg | fbs, chol, heartdisease)
# (sex _|_ thalach | chol, heartdisease, restecg)
# (sex _|_ fbs, heartdisease, restecg, chol | trestbps, thalach, age)
# (sex _|_ chol, heartdisease, restecg | trestbps, thalach, fbs)
# (sex _|_ chol, restecg | trestbps, thalach, heartdisease)
# (sex _|_ thalach, fbs, chol, heartdisease, restecg | trestbps, exang, age)
# (sex _|_ thalach, chol, heartdisease, restecg | trestbps, fbs, age)
# (sex _|_ thalach, chol, restecg, fbs | trestbps, heartdisease, age)
# (sex _|_ thalach, fbs, heartdisease, chol | trestbps, restecg, age)
# (sex _|_ thalach, chol, heartdisease, restecg | trestbps, fbs, exang)
# (sex _|_ thalach, chol, restecg | trestbps, heartdisease, exang)
# (sex _|_ thalach, chol, restecg | trestbps, fbs, heartdisease)
# (sex _|_ thalach, chol, heartdisease | trestbps, fbs, restecg)
# (sex _|_ thalach, chol | trestbps, heartdisease, restecg)
# (sex _|_ chol, restecg | thalach, heartdisease, age)
# (sex _|_ chol, restecg | thalach, heartdisease, exang)
# (sex _|_ chol, restecg | thalach, fbs, heartdisease)
# (sex _|_ chol | thalach, heartdisease, restecg)
# (sex _|_ thalach, chol, restecg | exang, heartdisease, age)
# (sex _|_ thalach, chol, restecg | fbs, heartdisease, age)
# (sex _|_ thalach, chol | heartdisease, restecg, age)
# (sex _|_ thalach, chol, restecg | exang, fbs, heartdisease)
# (sex _|_ thalach, chol | exang, heartdisease, restecg)
# (sex _|_ thalach, chol | fbs, heartdisease, restecg)
# (sex _|_ fbs, heartdisease, restecg | trestbps, chol, thalach, age)
# (sex _|_ heartdisease, restecg | trestbps, chol, thalach, fbs)
# (sex _|_ restecg | trestbps, chol, heartdisease, thalach)
# (sex _|_ thalach, fbs, heartdisease, restecg | trestbps, chol, exang, age)
# (sex _|_ thalach, heartdisease, restecg | trestbps, chol, age, fbs)
# (sex _|_ thalach, fbs, restecg | trestbps, chol, heartdisease, age)
# (sex _|_ thalach, fbs, heartdisease | trestbps, chol, restecg, age)
# (sex _|_ thalach, heartdisease, restecg | trestbps, chol, exang, fbs)
# (sex _|_ thalach, restecg | trestbps, chol, heartdisease, exang)
# (sex _|_ thalach, restecg | trestbps, chol, heartdisease, fbs)
# (sex _|_ thalach, heartdisease | trestbps, chol, restecg, fbs)
# (sex _|_ thalach | trestbps, chol, heartdisease, restecg)
# (sex _|_ restecg | thalach, chol, heartdisease, age)
# (sex _|_ restecg | thalach, chol, heartdisease, exang)
# (sex _|_ restecg | thalach, chol, heartdisease, fbs)
# (sex _|_ thalach, restecg | exang, chol, heartdisease, age)
# (sex _|_ thalach, restecg | fbs, chol, heartdisease, age)
# (sex _|_ thalach | chol, heartdisease, age, restecg)
# (sex _|_ thalach, restecg | exang, chol, heartdisease, fbs)
# (sex _|_ thalach | exang, chol, heartdisease, restecg)
# (sex _|_ thalach | fbs, chol, heartdisease, restecg)
# (sex _|_ fbs, heartdisease, restecg, chol | trestbps, thalach, exang, age)
# (sex _|_ chol, heartdisease, restecg | trestbps, thalach, age, fbs)
# (sex _|_ fbs, chol, restecg | trestbps, thalach, heartdisease, age)
# (sex _|_ fbs, chol, heartdisease | trestbps, thalach, restecg, age)
# (sex _|_ chol, heartdisease, restecg | trestbps, thalach, exang, fbs)
# (sex _|_ chol, restecg | trestbps, thalach, heartdisease, exang)
# (sex _|_ chol, restecg | trestbps, thalach, heartdisease, fbs)
# (sex _|_ chol, heartdisease | trestbps, thalach, restecg, fbs)
# (sex _|_ chol | trestbps, thalach, heartdisease, restecg)
# (sex _|_ thalach, chol, heartdisease, restecg | trestbps, fbs, exang, age)
# (sex _|_ thalach, chol, restecg, fbs | trestbps, heartdisease, exang, age)
# (sex _|_ thalach, chol, heartdisease, fbs | trestbps, restecg, exang, age)
# (sex _|_ thalach, chol, restecg | trestbps, fbs, heartdisease, age)
# (sex _|_ thalach, chol, heartdisease | trestbps, fbs, restecg, age)
# (sex _|_ thalach, chol, fbs | trestbps, heartdisease, restecg, age)
# (sex _|_ thalach, chol, restecg | trestbps, fbs, heartdisease, exang)
# (sex _|_ thalach, chol, heartdisease | trestbps, fbs, restecg, exang)
# (sex _|_ thalach, chol | trestbps, heartdisease, restecg, exang)
# (sex _|_ thalach, chol | trestbps, fbs, heartdisease, restecg)
# (sex _|_ chol, restecg | thalach, heartdisease, exang, age)
# (sex _|_ chol, restecg | thalach, fbs, heartdisease, age)
# (sex _|_ chol | thalach, heartdisease, restecg, age)
# (sex _|_ chol, restecg | thalach, fbs, heartdisease, exang)
# (sex _|_ chol | thalach, heartdisease, restecg, exang)
# (sex _|_ chol | thalach, fbs, heartdisease, restecg)
# (sex _|_ thalach, chol, restecg | exang, fbs, heartdisease, age)
# (sex _|_ thalach, chol | exang, heartdisease, restecg, age)
# (sex _|_ thalach, chol | fbs, heartdisease, age, restecg)
# (sex _|_ thalach, chol | exang, fbs, heartdisease, restecg)
# (sex _|_ fbs, heartdisease, restecg | chol, trestbps, thalach, age, exang)
# (sex _|_ heartdisease, restecg | chol, trestbps, thalach, age, fbs)
# (sex _|_ fbs, restecg | chol, trestbps, thalach, age, heartdisease)
# (sex _|_ fbs, heartdisease | chol, trestbps, thalach, age, restecg)
# (sex _|_ heartdisease, restecg | chol, trestbps, thalach, exang, fbs)
# (sex _|_ restecg | chol, trestbps, thalach, exang, heartdisease)
# (sex _|_ restecg | fbs, chol, trestbps, thalach, heartdisease)
# (sex _|_ heartdisease | chol, trestbps, thalach, fbs, restecg)
# (sex _|_ thalach, heartdisease, restecg | chol, trestbps, age, exang, fbs)
# (sex _|_ thalach, fbs, restecg | chol, trestbps, age, exang, heartdisease)
# (sex _|_ thalach, fbs, heartdisease | chol, trestbps, age, exang, restecg)
# (sex _|_ thalach, restecg | fbs, chol, trestbps, age, heartdisease)
# (sex _|_ thalach, heartdisease | chol, trestbps, age, fbs, restecg)
# (sex _|_ thalach, fbs | chol, trestbps, age, heartdisease, restecg)
# (sex _|_ thalach, restecg | fbs, chol, trestbps, exang, heartdisease)
# (sex _|_ thalach, heartdisease | chol, trestbps, exang, fbs, restecg)
# (sex _|_ thalach | chol, trestbps, exang, heartdisease, restecg)
# (sex _|_ thalach | fbs, chol, trestbps, heartdisease, restecg)
# (sex _|_ restecg | chol, thalach, age, exang, heartdisease)
# (sex _|_ restecg | fbs, chol, thalach, age, heartdisease)
# (sex _|_ restecg | fbs, chol, thalach, exang, heartdisease)
# (sex _|_ thalach, restecg | fbs, chol, age, exang, heartdisease)
# (sex _|_ thalach | chol, age, exang, heartdisease, restecg)
# (sex _|_ thalach | chol, age, fbs, heartdisease, restecg)
# (sex _|_ thalach | fbs, chol, exang, heartdisease, restecg)
# (sex _|_ chol, heartdisease, restecg | trestbps, thalach, age, exang, fbs)
# (sex _|_ fbs, restecg, chol | trestbps, thalach, age, exang, heartdisease)
# (sex _|_ fbs, heartdisease, chol | trestbps, thalach, age, exang, restecg)
# (sex _|_ chol, restecg | fbs, trestbps, thalach, age, heartdisease)
# (sex _|_ chol, heartdisease | trestbps, thalach, age, fbs, restecg)
# (sex _|_ fbs, chol | trestbps, thalach, age, heartdisease, restecg)
# (sex _|_ chol, restecg | fbs, trestbps, thalach, exang, heartdisease)
# (sex _|_ chol, heartdisease | trestbps, thalach, exang, fbs, restecg)
# (sex _|_ chol | trestbps, thalach, exang, heartdisease, restecg)
# (sex _|_ chol | fbs, trestbps, thalach, heartdisease, restecg)
# (sex _|_ thalach, chol, restecg | trestbps, age, exang, fbs, heartdisease)
# (sex _|_ thalach, chol, heartdisease | trestbps, age, exang, fbs, restecg)
# (sex _|_ thalach, chol, fbs | trestbps, age, exang, heartdisease, restecg)
# (sex _|_ thalach, chol | trestbps, age, fbs, heartdisease, restecg)
# (sex _|_ thalach, chol | trestbps, exang, fbs, heartdisease, restecg)
# (sex _|_ chol, restecg | thalach, age, exang, fbs, heartdisease)
# (sex _|_ chol | thalach, age, exang, heartdisease, restecg)
# (sex _|_ chol | thalach, age, fbs, heartdisease, restecg)
# (sex _|_ chol | thalach, exang, fbs, heartdisease, restecg)
# (sex _|_ thalach, chol | age, exang, fbs, heartdisease, restecg)
# (sex _|_ heartdisease, restecg | chol, trestbps, thalach, age, exang, fbs)
# (sex _|_ fbs, restecg | chol, trestbps, thalach, age, exang, heartdisease)
# (sex _|_ fbs, heartdisease | chol, trestbps, thalach, age, exang, restecg)
# (sex _|_ restecg | chol, trestbps, thalach, age, fbs, heartdisease)
# (sex _|_ heartdisease | chol, trestbps, thalach, age, fbs, restecg)
# (sex _|_ fbs | chol, trestbps, thalach, age, heartdisease, restecg)
# (sex _|_ restecg | chol, trestbps, thalach, exang, fbs, heartdisease)
# (sex _|_ heartdisease | chol, trestbps, thalach, exang, fbs, restecg)
# (sex _|_ thalach, restecg | chol, trestbps, age, exang, fbs, heartdisease)
# (sex _|_ thalach, heartdisease | chol, trestbps, age, exang, fbs, restecg)
# (sex _|_ thalach, fbs | chol, trestbps, age, exang, heartdisease, restecg)
# (sex _|_ thalach | fbs, chol, trestbps, age, heartdisease, restecg)
# (sex _|_ thalach | fbs, chol, trestbps, exang, heartdisease, restecg)
# (sex _|_ restecg | chol, thalach, age, exang, fbs, heartdisease)
# (sex _|_ thalach | fbs, chol, age, exang, heartdisease, restecg)
# (sex _|_ chol, restecg | trestbps, thalach, age, exang, fbs, heartdisease)
# (sex _|_ chol, heartdisease | trestbps, thalach, age, exang, fbs, restecg)
# (sex _|_ fbs, chol | trestbps, thalach, age, exang, heartdisease, restecg)
# (sex _|_ chol | fbs, trestbps, thalach, age, heartdisease, restecg)
# (sex _|_ chol | fbs, trestbps, thalach, exang, heartdisease, restecg)
# (sex _|_ thalach, chol | trestbps, age, exang, fbs, heartdisease, restecg)
# (sex _|_ chol | thalach, age, exang, fbs, heartdisease, restecg)
# (sex _|_ restecg | chol, trestbps, thalach, age, exang, fbs, heartdisease)
# (sex _|_ heartdisease | chol, trestbps, thalach, age, exang, fbs, restecg)
# (sex _|_ fbs | chol, trestbps, thalach, age, exang, heartdisease, restecg)
# (sex _|_ thalach | chol, trestbps, age, exang, fbs, heartdisease, restecg)
# (sex _|_ chol | trestbps, thalach, age, exang, fbs, heartdisease, restecg)
# (exang _|_ fbs, sex, age)
# (exang _|_ fbs, sex | age)
# (exang _|_ sex, age | fbs)
# (exang _|_ thalach, chol, restecg | heartdisease)
# (exang _|_ fbs, age | sex)
# (exang _|_ thalach, restecg | chol, heartdisease)
# (exang _|_ thalach, fbs, chol, heartdisease, restecg | trestbps, age)
# (exang _|_ thalach, chol, heartdisease, restecg | trestbps, fbs)
# (exang _|_ thalach, chol, restecg | trestbps, heartdisease)
# (exang _|_ chol, restecg | thalach, heartdisease)
# (exang _|_ sex | fbs, age)
# (exang _|_ thalach, chol, restecg | heartdisease, age)
# (exang _|_ fbs | sex, age)
# (exang _|_ thalach, chol, restecg | fbs, heartdisease)
# (exang _|_ age | fbs, sex)
# (exang _|_ thalach, chol, restecg | heartdisease, sex)
# (exang _|_ thalach, chol | heartdisease, restecg)
# (exang _|_ thalach, fbs, heartdisease, restecg | trestbps, chol, age)
# (exang _|_ thalach, heartdisease, restecg | trestbps, chol, fbs)
# (exang _|_ thalach, restecg | trestbps, chol, heartdisease)
# (exang _|_ restecg | thalach, chol, heartdisease)
# (exang _|_ thalach, restecg | chol, heartdisease, age)
# (exang _|_ thalach, restecg | fbs, chol, heartdisease)
# (exang _|_ thalach, restecg | chol, heartdisease, sex)
# (exang _|_ thalach | chol, heartdisease, restecg)
# (exang _|_ fbs, chol, heartdisease, restecg | trestbps, thalach, age)
# (exang _|_ chol, heartdisease, restecg | trestbps, thalach, fbs)
# (exang _|_ chol, restecg | trestbps, thalach, heartdisease)
# (exang _|_ thalach, chol, heartdisease, restecg | trestbps, fbs, age)
# (exang _|_ thalach, fbs, restecg, chol | trestbps, heartdisease, age)
# (exang _|_ thalach, fbs, chol, heartdisease, restecg | trestbps, sex, age)
# (exang _|_ thalach, fbs, heartdisease, chol | trestbps, restecg, age)
# (exang _|_ thalach, chol, restecg | trestbps, fbs, heartdisease)
# (exang _|_ thalach, chol, heartdisease, restecg | trestbps, fbs, sex)
# (exang _|_ thalach, chol, heartdisease | trestbps, fbs, restecg)
# (exang _|_ thalach, chol, restecg | trestbps, heartdisease, sex)
# (exang _|_ thalach, chol | trestbps, heartdisease, restecg)
# (exang _|_ chol, restecg | thalach, heartdisease, age)
# (exang _|_ chol, restecg | thalach, fbs, heartdisease)
# (exang _|_ chol, restecg | thalach, heartdisease, sex)
# (exang _|_ chol | thalach, heartdisease, restecg)
# (exang _|_ thalach, chol, restecg | fbs, heartdisease, age)
# (exang _|_ thalach, chol, restecg | heartdisease, sex, age)
# (exang _|_ thalach, chol | heartdisease, restecg, age)
# (exang _|_ thalach, chol, restecg | fbs, heartdisease, sex)
# (exang _|_ thalach, chol | fbs, heartdisease, restecg)
# (exang _|_ thalach, chol | heartdisease, restecg, sex)
# (exang _|_ fbs, heartdisease, restecg | trestbps, chol, thalach, age)
# (exang _|_ heartdisease, restecg | trestbps, chol, thalach, fbs)
# (exang _|_ restecg | trestbps, chol, heartdisease, thalach)
# (exang _|_ thalach, heartdisease, restecg | trestbps, chol, age, fbs)
# (exang _|_ thalach, fbs, restecg | trestbps, chol, heartdisease, age)
# (exang _|_ thalach, fbs, heartdisease, restecg | trestbps, chol, sex, age)
# (exang _|_ thalach, fbs, heartdisease | trestbps, chol, restecg, age)
# (exang _|_ thalach, restecg | trestbps, chol, heartdisease, fbs)
# (exang _|_ thalach, heartdisease, restecg | trestbps, chol, sex, fbs)
# (exang _|_ thalach, heartdisease | trestbps, chol, restecg, fbs)
# (exang _|_ thalach, restecg | trestbps, chol, heartdisease, sex)
# (exang _|_ thalach | trestbps, chol, heartdisease, restecg)
# (exang _|_ restecg | thalach, chol, heartdisease, age)
# (exang _|_ restecg | thalach, chol, heartdisease, fbs)
# (exang _|_ restecg | thalach, chol, heartdisease, sex)
# (exang _|_ thalach, restecg | fbs, chol, heartdisease, age)
# (exang _|_ thalach, restecg | chol, heartdisease, sex, age)
# (exang _|_ thalach | chol, heartdisease, age, restecg)
# (exang _|_ thalach, restecg | fbs, chol, heartdisease, sex)
# (exang _|_ thalach | fbs, chol, heartdisease, restecg)
# (exang _|_ thalach | chol, heartdisease, sex, restecg)
# (exang _|_ chol, heartdisease, restecg | trestbps, thalach, age, fbs)
# (exang _|_ fbs, restecg, chol | trestbps, thalach, heartdisease, age)
# (exang _|_ fbs, heartdisease, restecg, chol | trestbps, thalach, sex, age)
# (exang _|_ fbs, heartdisease, chol | trestbps, thalach, restecg, age)
# (exang _|_ chol, restecg | trestbps, thalach, heartdisease, fbs)
# (exang _|_ chol, heartdisease, restecg | trestbps, thalach, sex, fbs)
# (exang _|_ chol, heartdisease | trestbps, thalach, restecg, fbs)
# (exang _|_ chol, restecg | trestbps, thalach, heartdisease, sex)
# (exang _|_ chol | trestbps, thalach, heartdisease, restecg)
# (exang _|_ thalach, chol, restecg | trestbps, fbs, heartdisease, age)
# (exang _|_ thalach, chol, heartdisease, restecg | trestbps, fbs, sex, age)
# (exang _|_ thalach, chol, heartdisease | trestbps, fbs, restecg, age)
# (exang _|_ thalach, chol, restecg, fbs | trestbps, heartdisease, sex, age)
# (exang _|_ thalach, chol, fbs | trestbps, heartdisease, restecg, age)
# (exang _|_ thalach, chol, heartdisease, fbs | trestbps, sex, restecg, age)
# (exang _|_ thalach, chol, restecg | trestbps, fbs, heartdisease, sex)
# (exang _|_ thalach, chol | trestbps, fbs, heartdisease, restecg)
# (exang _|_ thalach, chol, heartdisease | trestbps, fbs, restecg, sex)
# (exang _|_ thalach, chol | trestbps, heartdisease, restecg, sex)
# (exang _|_ chol, restecg | thalach, fbs, heartdisease, age)
# (exang _|_ chol, restecg | thalach, heartdisease, sex, age)
# (exang _|_ chol | thalach, heartdisease, restecg, age)
# (exang _|_ chol, restecg | thalach, fbs, heartdisease, sex)
# (exang _|_ chol | thalach, fbs, heartdisease, restecg)
# (exang _|_ chol | thalach, heartdisease, restecg, sex)
# (exang _|_ thalach, chol, restecg | fbs, heartdisease, sex, age)
# (exang _|_ thalach, chol | fbs, heartdisease, age, restecg)
# (exang _|_ thalach, chol | heartdisease, restecg, sex, age)
# (exang _|_ thalach, chol | fbs, heartdisease, sex, restecg)
# (exang _|_ heartdisease, restecg | chol, trestbps, thalach, age, fbs)
# (exang _|_ fbs, restecg | chol, trestbps, thalach, age, heartdisease)
# (exang _|_ fbs, heartdisease, restecg | chol, trestbps, thalach, age, sex)
# (exang _|_ fbs, heartdisease | chol, trestbps, thalach, age, restecg)
# (exang _|_ restecg | fbs, chol, trestbps, thalach, heartdisease)
# (exang _|_ heartdisease, restecg | fbs, chol, trestbps, thalach, sex)
# (exang _|_ heartdisease | chol, trestbps, thalach, fbs, restecg)
# (exang _|_ restecg | chol, trestbps, thalach, heartdisease, sex)
# (exang _|_ thalach, restecg | fbs, chol, trestbps, age, heartdisease)
# (exang _|_ thalach, heartdisease, restecg | fbs, chol, trestbps, age, sex)
# (exang _|_ thalach, heartdisease | chol, trestbps, age, fbs, restecg)
# (exang _|_ thalach, fbs, restecg | chol, trestbps, age, heartdisease, sex)
# (exang _|_ thalach, fbs | chol, trestbps, age, heartdisease, restecg)
# (exang _|_ thalach, fbs, heartdisease | chol, trestbps, age, sex, restecg)
# (exang _|_ thalach, restecg | fbs, chol, trestbps, heartdisease, sex)
# (exang _|_ thalach | fbs, chol, trestbps, heartdisease, restecg)
# (exang _|_ thalach, heartdisease | fbs, chol, trestbps, sex, restecg)
# (exang _|_ thalach | chol, trestbps, heartdisease, restecg, sex)
# (exang _|_ restecg | fbs, chol, thalach, age, heartdisease)
# (exang _|_ restecg | chol, thalach, age, heartdisease, sex)
# (exang _|_ restecg | fbs, chol, thalach, heartdisease, sex)
# (exang _|_ thalach, restecg | chol, age, fbs, heartdisease, sex)
# (exang _|_ thalach | chol, age, fbs, heartdisease, restecg)
# (exang _|_ thalach | chol, age, heartdisease, restecg, sex)
# (exang _|_ thalach | chol, fbs, heartdisease, sex, restecg)
# (exang _|_ chol, restecg | fbs, trestbps, thalach, age, heartdisease)
# (exang _|_ chol, heartdisease, restecg | fbs, trestbps, thalach, age, sex)
# (exang _|_ chol, heartdisease | trestbps, thalach, age, fbs, restecg)
# (exang _|_ fbs, restecg, chol | trestbps, thalach, age, heartdisease, sex)
# (exang _|_ fbs, chol | trestbps, thalach, age, heartdisease, restecg)
# (exang _|_ fbs, heartdisease, chol | trestbps, thalach, age, sex, restecg)
# (exang _|_ chol, restecg | fbs, trestbps, thalach, heartdisease, sex)
# (exang _|_ chol | fbs, trestbps, thalach, heartdisease, restecg)
# (exang _|_ chol, heartdisease | fbs, trestbps, thalach, sex, restecg)
# (exang _|_ chol | trestbps, thalach, heartdisease, restecg, sex)
# (exang _|_ thalach, chol, restecg | trestbps, age, fbs, heartdisease, sex)
# (exang _|_ thalach, chol | trestbps, age, fbs, heartdisease, restecg)
# (exang _|_ thalach, chol, heartdisease | trestbps, age, fbs, restecg, sex)
# (exang _|_ thalach, chol, fbs | trestbps, age, heartdisease, restecg, sex)
# (exang _|_ thalach, chol | trestbps, fbs, heartdisease, sex, restecg)
# (exang _|_ chol, restecg | thalach, age, fbs, heartdisease, sex)
# (exang _|_ chol | thalach, age, fbs, heartdisease, restecg)
# (exang _|_ chol | thalach, age, heartdisease, restecg, sex)
# (exang _|_ chol | thalach, fbs, heartdisease, sex, restecg)
# (exang _|_ thalach, chol | age, fbs, heartdisease, sex, restecg)
# (exang _|_ restecg | chol, trestbps, thalach, age, fbs, heartdisease)
# (exang _|_ heartdisease, restecg | chol, trestbps, thalach, age, fbs, sex)
# (exang _|_ heartdisease | chol, trestbps, thalach, age, fbs, restecg)
# (exang _|_ fbs, restecg | chol, trestbps, thalach, age, heartdisease, sex)
# (exang _|_ fbs | chol, trestbps, thalach, age, heartdisease, restecg)
# (exang _|_ fbs, heartdisease | chol, trestbps, thalach, age, sex, restecg)
# (exang _|_ restecg | fbs, chol, trestbps, thalach, heartdisease, sex)
# (exang _|_ heartdisease | fbs, chol, trestbps, thalach, sex, restecg)
# (exang _|_ thalach, restecg | fbs, chol, trestbps, age, heartdisease, sex)
# (exang _|_ thalach | fbs, chol, trestbps, age, heartdisease, restecg)
# (exang _|_ thalach, heartdisease | fbs, chol, trestbps, age, sex, restecg)
# (exang _|_ thalach, fbs | chol, trestbps, age, heartdisease, restecg, sex)
# (exang _|_ thalach | fbs, chol, trestbps, heartdisease, restecg, sex)
# (exang _|_ restecg | fbs, chol, thalach, age, heartdisease, sex)
# (exang _|_ thalach | chol, age, fbs, heartdisease, sex, restecg)
# (exang _|_ chol, restecg | fbs, trestbps, thalach, age, heartdisease, sex)
# (exang _|_ chol | fbs, trestbps, thalach, age, heartdisease, restecg)
# (exang _|_ chol, heartdisease | fbs, trestbps, thalach, age, sex, restecg)
# (exang _|_ fbs, chol | trestbps, thalach, age, heartdisease, restecg, sex)
# (exang _|_ chol | fbs, trestbps, thalach, heartdisease, restecg, sex)
# (exang _|_ thalach, chol | trestbps, age, fbs, heartdisease, sex, restecg)
# (exang _|_ chol | thalach, age, fbs, heartdisease, sex, restecg)
# (exang _|_ restecg | chol, trestbps, thalach, age, fbs, heartdisease, sex)
# (exang _|_ heartdisease | chol, trestbps, thalach, age, fbs, restecg, sex)
# (exang _|_ fbs | chol, trestbps, thalach, age, heartdisease, restecg, sex)
# (exang _|_ thalach | fbs, chol, trestbps, age, heartdisease, restecg, sex)
# (exang _|_ chol | fbs, trestbps, thalach, age, heartdisease, restecg, sex)
# (heartdisease _|_ exang, sex | trestbps, age)
# (heartdisease _|_ exang, sex, age | trestbps, fbs)
# (heartdisease _|_ exang, sex | trestbps, chol, age)
# (heartdisease _|_ exang, sex, age | trestbps, chol, fbs)
# (heartdisease _|_ exang, sex | trestbps, thalach, age)
# (heartdisease _|_ exang, sex, age | trestbps, thalach, fbs)
# (heartdisease _|_ sex | trestbps, exang, age)
# (heartdisease _|_ exang, sex | trestbps, fbs, age)
# (heartdisease _|_ exang | trestbps, sex, age)
# (heartdisease _|_ exang, sex | trestbps, restecg, age)
# (heartdisease _|_ sex, age | trestbps, fbs, exang)
# (heartdisease _|_ exang, age | trestbps, fbs, sex)
# (heartdisease _|_ exang, sex, age | trestbps, fbs, restecg)
# (heartdisease _|_ exang, sex | trestbps, chol, thalach, age)
# (heartdisease _|_ exang, sex, age | trestbps, chol, thalach, fbs)
# (heartdisease _|_ sex | trestbps, chol, exang, age)
# (heartdisease _|_ exang, sex | trestbps, chol, age, fbs)
# (heartdisease _|_ exang | trestbps, chol, sex, age)
# (heartdisease _|_ exang, sex | trestbps, chol, restecg, age)
# (heartdisease _|_ sex, age | trestbps, chol, exang, fbs)
# (heartdisease _|_ exang, age | trestbps, chol, sex, fbs)
# (heartdisease _|_ exang, sex, age | trestbps, chol, restecg, fbs)
# (heartdisease _|_ sex | trestbps, thalach, exang, age)
# (heartdisease _|_ exang, sex | trestbps, thalach, age, fbs)
# ...
# (thalach _|_ exang, fbs, age | chol, trestbps, heartdisease, restecg, sex)
# (thalach _|_ trestbps, sex, restecg | fbs, chol, age, exang, heartdisease)
# (thalach _|_ trestbps, fbs, restecg | chol, age, exang, heartdisease, sex)
# (thalach _|_ trestbps, fbs, sex | chol, age, exang, heartdisease, restecg)
# (thalach _|_ trestbps, restecg, exang | chol, age, fbs, heartdisease, sex)
# (thalach _|_ trestbps, sex, exang | chol, age, fbs, heartdisease, restecg)
# (thalach _|_ trestbps, fbs, exang | chol, age, heartdisease, restecg, sex)
# (thalach _|_ trestbps, restecg, age | fbs, chol, exang, heartdisease, sex)
# (thalach _|_ trestbps, sex, age | fbs, chol, exang, heartdisease, restecg)
# (thalach _|_ trestbps, fbs, age | chol, exang, heartdisease, restecg, sex)
# (thalach _|_ trestbps, exang, age | chol, fbs, heartdisease, sex, restecg)
# (thalach _|_ chol, restecg, sex | trestbps, age, exang, fbs, heartdisease)
# (thalach _|_ sex | trestbps, age, exang, fbs, restecg)
# (thalach _|_ fbs, restecg, chol | trestbps, age, exang, heartdisease, sex)
# (thalach _|_ fbs, sex, chol | trestbps, age, exang, heartdisease, restecg)
# (thalach _|_ exang, chol, restecg | trestbps, age, fbs, heartdisease, sex)
# (thalach _|_ exang, chol, sex | trestbps, age, fbs, heartdisease, restecg)
# (thalach _|_ exang | trestbps, age, fbs, restecg, sex)
# (thalach _|_ exang, chol, fbs | trestbps, age, heartdisease, restecg, sex)
# (thalach _|_ chol, restecg, age | trestbps, exang, fbs, heartdisease, sex)
# (thalach _|_ chol, sex, age | trestbps, exang, fbs, heartdisease, restecg)
# (thalach _|_ age | trestbps, exang, fbs, restecg, sex)
# (thalach _|_ fbs, age, chol | trestbps, exang, heartdisease, restecg, sex)
# (thalach _|_ exang, chol, age | trestbps, fbs, heartdisease, sex, restecg)
# (thalach _|_ trestbps, chol, restecg | age, exang, fbs, heartdisease, sex)
# (thalach _|_ trestbps, chol, sex | age, exang, fbs, heartdisease, restecg)
# (thalach _|_ trestbps, chol, fbs | age, exang, heartdisease, restecg, sex)
# (thalach _|_ trestbps, chol, exang | age, fbs, heartdisease, sex, restecg)
# (thalach _|_ trestbps, chol, age | exang, fbs, heartdisease, sex, restecg)
# (thalach _|_ sex, restecg | chol, trestbps, age, exang, fbs, heartdisease)
# (thalach _|_ sex | chol, trestbps, age, exang, fbs, restecg)
# (thalach _|_ fbs, restecg | chol, trestbps, age, exang, heartdisease, sex)
# (thalach _|_ fbs, sex | chol, trestbps, age, exang, heartdisease, restecg)
# (thalach _|_ exang, restecg | fbs, chol, trestbps, age, heartdisease, sex)
# (thalach _|_ exang, sex | fbs, chol, trestbps, age, heartdisease, restecg)
# (thalach _|_ exang | fbs, chol, trestbps, age, sex, restecg)
# (thalach _|_ exang, fbs | chol, trestbps, age, heartdisease, restecg, sex)
# (thalach _|_ restecg, age | fbs, chol, trestbps, exang, heartdisease, sex)
# (thalach _|_ sex, age | fbs, chol, trestbps, exang, heartdisease, restecg)
# (thalach _|_ age | fbs, chol, trestbps, exang, sex, restecg)
# (thalach _|_ fbs, age | chol, trestbps, exang, heartdisease, restecg, sex)
# (thalach _|_ exang, age | fbs, chol, trestbps, heartdisease, restecg, sex)
# (thalach _|_ trestbps, restecg | fbs, chol, age, exang, heartdisease, sex)
# (thalach _|_ trestbps, sex | fbs, chol, age, exang, heartdisease, restecg)
# (thalach _|_ trestbps, fbs | chol, age, exang, heartdisease, restecg, sex)
# (thalach _|_ trestbps, exang | chol, age, fbs, heartdisease, sex, restecg)
# (thalach _|_ trestbps, age | fbs, chol, exang, heartdisease, restecg, sex)
# (thalach _|_ chol, restecg | trestbps, age, exang, fbs, heartdisease, sex)
# (thalach _|_ chol, sex | trestbps, age, exang, fbs, heartdisease, restecg)
# (thalach _|_ fbs, chol | trestbps, age, exang, heartdisease, restecg, sex)
# (thalach _|_ exang, chol | trestbps, age, fbs, heartdisease, sex, restecg)
# (thalach _|_ chol, age | trestbps, exang, fbs, heartdisease, sex, restecg)
# (thalach _|_ trestbps, chol | age, exang, fbs, heartdisease, sex, restecg)
# (thalach _|_ restecg | chol, trestbps, age, exang, fbs, heartdisease, sex)
# (thalach _|_ sex | chol, trestbps, age, exang, fbs, heartdisease, restecg)
# (thalach _|_ fbs | chol, trestbps, age, exang, heartdisease, restecg, sex)
# (thalach _|_ exang | fbs, chol, trestbps, age, heartdisease, restecg, sex)
# (thalach _|_ age | fbs, chol, trestbps, exang, heartdisease, restecg, sex)
# (thalach _|_ trestbps | fbs, chol, age, exang, heartdisease, restecg, sex)
# (thalach _|_ chol | trestbps, age, exang, fbs, heartdisease, sex, restecg)
# (chol _|_ trestbps, thalach, age, exang, fbs, restecg, sex | heartdisease)
# (chol _|_ exang, sex | trestbps, age)
# (chol _|_ exang, sex, age | trestbps, fbs)
# (chol _|_ thalach, age, exang, fbs, restecg, sex | trestbps, heartdisease)
# (chol _|_ trestbps, age, exang, fbs, restecg, sex | thalach, heartdisease)
# (chol _|_ trestbps, thalach, exang, fbs, restecg, sex | heartdisease, age)
# (chol _|_ trestbps, thalach, age, fbs, restecg, sex | exang, heartdisease)
# (chol _|_ trestbps, thalach, age, exang, sex, restecg | fbs, heartdisease)
# (chol _|_ trestbps, thalach, age, exang, fbs, restecg | heartdisease, sex)
# (chol _|_ trestbps, thalach, age, exang, fbs, sex | heartdisease, restecg)
# (chol _|_ exang, sex | trestbps, thalach, age)
# (chol _|_ exang, sex, age | trestbps, thalach, fbs)
# (chol _|_ age, exang, fbs, restecg, sex | trestbps, thalach, heartdisease)
# (chol _|_ sex | trestbps, exang, age)
# (chol _|_ exang, sex | trestbps, fbs, age)
# (chol _|_ thalach, exang, fbs, restecg, sex | trestbps, heartdisease, age)
# (chol _|_ exang | trestbps, sex, age)
# (chol _|_ exang, sex | trestbps, restecg, age)
# (chol _|_ sex, age | trestbps, fbs, exang)
# (chol _|_ thalach, age, fbs, restecg, sex | trestbps, heartdisease, exang)
# (chol _|_ thalach, age, exang, sex, restecg | trestbps, fbs, heartdisease)
# (chol _|_ exang, age | trestbps, fbs, sex)
# (chol _|_ exang, sex, age | trestbps, fbs, restecg)
# (chol _|_ thalach, age, exang, fbs, restecg | trestbps, heartdisease, sex)
# (chol _|_ thalach, age, exang, fbs, sex | trestbps, heartdisease, restecg)
# (chol _|_ trestbps, exang, fbs, restecg, sex | thalach, heartdisease, age)
# (chol _|_ trestbps, age, fbs, restecg, sex | thalach, heartdisease, exang)
# (chol _|_ trestbps, age, exang, sex, restecg | thalach, fbs, heartdisease)
# (chol _|_ trestbps, age, exang, fbs, restecg | thalach, heartdisease, sex)
# (chol _|_ trestbps, age, exang, fbs, sex | thalach, heartdisease, restecg)
# (chol _|_ trestbps, thalach, fbs, restecg, sex | exang, heartdisease, age)
# (chol _|_ trestbps, thalach, exang, sex, restecg | fbs, heartdisease, age)
# (chol _|_ trestbps, thalach, exang, fbs, restecg | heartdisease, sex, age)
# (chol _|_ trestbps, thalach, exang, fbs, sex | heartdisease, restecg, age)
# (chol _|_ trestbps, thalach, age, sex, restecg | exang, fbs, heartdisease)
# (chol _|_ trestbps, thalach, age, fbs, restecg | exang, heartdisease, sex)
# (chol _|_ trestbps, thalach, age, fbs, sex | exang, heartdisease, restecg)
# (chol _|_ trestbps, thalach, age, exang, restecg | fbs, heartdisease, sex)
# (chol _|_ trestbps, thalach, age, exang, sex | fbs, heartdisease, restecg)
# (chol _|_ trestbps, thalach, age, exang, fbs | heartdisease, restecg, sex)
# (chol _|_ sex | trestbps, thalach, exang, age)
# (chol _|_ exang, sex | trestbps, thalach, age, fbs)
# (chol _|_ exang, fbs, restecg, sex | trestbps, thalach, heartdisease, age)
# (chol _|_ exang | trestbps, thalach, sex, age)
# (chol _|_ exang, sex | trestbps, thalach, restecg, age)
# (chol _|_ sex, age | trestbps, thalach, exang, fbs)
# (chol _|_ fbs, restecg, sex, age | trestbps, thalach, heartdisease, exang)
# (chol _|_ exang, sex, restecg, age | trestbps, thalach, heartdisease, fbs)
# (chol _|_ exang, age | trestbps, thalach, sex, fbs)
# (chol _|_ exang, sex, age | trestbps, thalach, restecg, fbs)
# (chol _|_ exang, fbs, restecg, age | trestbps, thalach, heartdisease, sex)
# (chol _|_ exang, fbs, sex, age | trestbps, thalach, heartdisease, restecg)
# (chol _|_ sex | trestbps, fbs, exang, age)
# (chol _|_ thalach, fbs, restecg, sex | trestbps, heartdisease, exang, age)
# (chol _|_ sex | trestbps, restecg, exang, age)
# (chol _|_ thalach, sex, restecg, exang | trestbps, fbs, heartdisease, age)
# (chol _|_ exang | trestbps, fbs, sex, age)
# (chol _|_ exang, sex | trestbps, fbs, restecg, age)
# (chol _|_ thalach, fbs, restecg, exang | trestbps, heartdisease, sex, age)
# (chol _|_ thalach, fbs, sex, exang | trestbps, heartdisease, restecg, age)
# (chol _|_ exang | trestbps, sex, restecg, age)
# (chol _|_ thalach, sex, restecg, age | trestbps, fbs, heartdisease, exang)
# (chol _|_ age | trestbps, fbs, sex, exang)
# (chol _|_ sex, age | trestbps, fbs, restecg, exang)
# (chol _|_ thalach, fbs, restecg, age | trestbps, heartdisease, sex, exang)
# (chol _|_ thalach, fbs, sex, age | trestbps, heartdisease, restecg, exang)
# (chol _|_ thalach, restecg, exang, age | trestbps, fbs, heartdisease, sex)
# (chol _|_ thalach, sex, exang, age | trestbps, fbs, heartdisease, restecg)
# (chol _|_ exang, age | trestbps, fbs, restecg, sex)
# (chol _|_ thalach, fbs, exang, age | trestbps, heartdisease, restecg, sex)
# (chol _|_ trestbps, fbs, restecg, sex | thalach, heartdisease, exang, age)
# (chol _|_ trestbps, sex, restecg, exang | thalach, fbs, heartdisease, age)
# (chol _|_ trestbps, fbs, restecg, exang | thalach, heartdisease, sex, age)
# (chol _|_ trestbps, fbs, sex, exang | thalach, heartdisease, restecg, age)
# (chol _|_ trestbps, sex, restecg, age | thalach, fbs, heartdisease, exang)
# (chol _|_ trestbps, fbs, restecg, age | thalach, heartdisease, sex, exang)
# (chol _|_ trestbps, fbs, sex, age | thalach, heartdisease, restecg, exang)
# (chol _|_ trestbps, restecg, exang, age | thalach, fbs, heartdisease, sex)
# (chol _|_ trestbps, sex, exang, age | thalach, fbs, heartdisease, restecg)
# (chol _|_ trestbps, fbs, exang, age | thalach, heartdisease, restecg, sex)
# (chol _|_ trestbps, thalach, restecg, sex | exang, fbs, heartdisease, age)
# (chol _|_ trestbps, thalach, restecg, fbs | exang, heartdisease, sex, age)
# (chol _|_ trestbps, thalach, sex, fbs | exang, heartdisease, restecg, age)
# (chol _|_ trestbps, thalach, restecg, exang | fbs, heartdisease, sex, age)
# (chol _|_ trestbps, thalach, sex, exang | fbs, heartdisease, age, restecg)
# (chol _|_ trestbps, thalach, exang, fbs | heartdisease, restecg, sex, age)
# (chol _|_ trestbps, thalach, restecg, age | exang, fbs, heartdisease, sex)
# (chol _|_ trestbps, thalach, sex, age | exang, fbs, heartdisease, restecg)
# (chol _|_ trestbps, thalach, age, fbs | exang, heartdisease, restecg, sex)
# (chol _|_ trestbps, thalach, exang, age | fbs, heartdisease, sex, restecg)
# (chol _|_ sex | trestbps, thalach, age, exang, fbs)
# (chol _|_ fbs, restecg, sex | trestbps, thalach, age, exang, heartdisease)
# (chol _|_ sex | trestbps, thalach, age, exang, restecg)
# (chol _|_ exang, sex, restecg | fbs, trestbps, thalach, age, heartdisease)
# (chol _|_ exang | fbs, trestbps, thalach, age, sex)
# (chol _|_ exang, sex | trestbps, thalach, age, fbs, restecg)
# (chol _|_ exang, fbs, restecg | trestbps, thalach, age, heartdisease, sex)
# (chol _|_ exang, fbs, sex | trestbps, thalach, age, heartdisease, restecg)
# (chol _|_ exang | trestbps, thalach, age, sex, restecg)
# (chol _|_ sex, restecg, age | fbs, trestbps, thalach, exang, heartdisease)
# (chol _|_ age | fbs, trestbps, thalach, exang, sex)
# (chol _|_ sex, age | trestbps, thalach, exang, fbs, restecg)
# (chol _|_ fbs, restecg, age | trestbps, thalach, exang, heartdisease, sex)
# (chol _|_ fbs, sex, age | trestbps, thalach, exang, heartdisease, restecg)
# (chol _|_ exang, restecg, age | fbs, trestbps, thalach, heartdisease, sex)
# (chol _|_ exang, sex, age | fbs, trestbps, thalach, heartdisease, restecg)
# (chol _|_ exang, age | fbs, trestbps, thalach, sex, restecg)
# (chol _|_ exang, fbs, age | trestbps, thalach, heartdisease, restecg, sex)
# (chol _|_ thalach, sex, restecg | trestbps, age, exang, fbs, heartdisease)
# (chol _|_ sex | trestbps, age, exang, fbs, restecg)
# (chol _|_ thalach, fbs, restecg | trestbps, age, exang, heartdisease, sex)
# (chol _|_ thalach, fbs, sex | trestbps, age, exang, heartdisease, restecg)
# (chol _|_ thalach, restecg, exang | trestbps, age, fbs, heartdisease, sex)
# (chol _|_ thalach, sex, exang | trestbps, age, fbs, heartdisease, restecg)
# (chol _|_ exang | trestbps, age, fbs, restecg, sex)
# (chol _|_ thalach, fbs, exang | trestbps, age, heartdisease, restecg, sex)
# (chol _|_ thalach, restecg, age | trestbps, exang, fbs, heartdisease, sex)
# (chol _|_ thalach, sex, age | trestbps, exang, fbs, heartdisease, restecg)
# (chol _|_ age | trestbps, exang, fbs, restecg, sex)
# (chol _|_ thalach, fbs, age | trestbps, exang, heartdisease, restecg, sex)
# (chol _|_ thalach, exang, age | trestbps, fbs, heartdisease, sex, restecg)
# (chol _|_ trestbps, sex, restecg | thalach, age, exang, fbs, heartdisease)
# (chol _|_ trestbps, fbs, restecg | thalach, age, exang, heartdisease, sex)
# (chol _|_ trestbps, fbs, sex | thalach, age, exang, heartdisease, restecg)
# (chol _|_ trestbps, restecg, exang | thalach, age, fbs, heartdisease, sex)
# (chol _|_ trestbps, sex, exang | thalach, age, fbs, heartdisease, restecg)
# (chol _|_ trestbps, fbs, exang | thalach, age, heartdisease, restecg, sex)
# (chol _|_ trestbps, restecg, age | thalach, exang, fbs, heartdisease, sex)
# (chol _|_ trestbps, sex, age | thalach, exang, fbs, heartdisease, restecg)
# (chol _|_ trestbps, fbs, age | thalach, exang, heartdisease, restecg, sex)
# (chol _|_ trestbps, exang, age | thalach, fbs, heartdisease, sex, restecg)
# (chol _|_ trestbps, thalach, restecg | age, exang, fbs, heartdisease, sex)
# (chol _|_ trestbps, thalach, sex | age, exang, fbs, heartdisease, restecg)
# (chol _|_ trestbps, thalach, fbs | age, exang, heartdisease, restecg, sex)
# (chol _|_ trestbps, thalach, exang | age, fbs, heartdisease, sex, restecg)
# (chol _|_ trestbps, thalach, age | exang, fbs, heartdisease, sex, restecg)
# (chol _|_ sex, restecg | trestbps, thalach, age, exang, fbs, heartdisease)
# (chol _|_ sex | trestbps, thalach, age, exang, fbs, restecg)
# (chol _|_ fbs, restecg | trestbps, thalach, age, exang, heartdisease, sex)
# (chol _|_ fbs, sex | trestbps, thalach, age, exang, heartdisease, restecg)
# (chol _|_ exang, restecg | fbs, trestbps, thalach, age, heartdisease, sex)
# (chol _|_ exang, sex | fbs, trestbps, thalach, age, heartdisease, restecg)
# (chol _|_ exang | fbs, trestbps, thalach, age, sex, restecg)
# (chol _|_ exang, fbs | trestbps, thalach, age, heartdisease, restecg, sex)
# (chol _|_ restecg, age | fbs, trestbps, thalach, exang, heartdisease, sex)
# (chol _|_ sex, age | fbs, trestbps, thalach, exang, heartdisease, restecg)
# (chol _|_ age | fbs, trestbps, thalach, exang, sex, restecg)
# (chol _|_ fbs, age | trestbps, thalach, exang, heartdisease, restecg, sex)
# (chol _|_ exang, age | fbs, trestbps, thalach, heartdisease, restecg, sex)
# (chol _|_ thalach, restecg | trestbps, age, exang, fbs, heartdisease, sex)
# (chol _|_ thalach, sex | trestbps, age, exang, fbs, heartdisease, restecg)
# (chol _|_ thalach, fbs | trestbps, age, exang, heartdisease, restecg, sex)
# (chol _|_ thalach, exang | trestbps, age, fbs, heartdisease, sex, restecg)
# (chol _|_ thalach, age | trestbps, exang, fbs, heartdisease, sex, restecg)
# (chol _|_ trestbps, restecg | thalach, age, exang, fbs, heartdisease, sex)
# (chol _|_ trestbps, sex | thalach, age, exang, fbs, heartdisease, restecg)
# (chol _|_ trestbps, fbs | thalach, age, exang, heartdisease, restecg, sex)
# (chol _|_ trestbps, exang | thalach, age, fbs, heartdisease, sex, restecg)
# (chol _|_ trestbps, age | thalach, exang, fbs, heartdisease, sex, restecg)
# (chol _|_ trestbps, thalach | age, exang, fbs, heartdisease, sex, restecg)
# (chol _|_ restecg | trestbps, thalach, age, exang, fbs, heartdisease, sex)
# (chol _|_ sex | trestbps, thalach, age, exang, fbs, heartdisease, restecg)
# (chol _|_ fbs | trestbps, thalach, age, exang, heartdisease, restecg, sex)
# (chol _|_ exang | fbs, trestbps, thalach, age, heartdisease, restecg, sex)
# (chol _|_ age | fbs, trestbps, thalach, exang, heartdisease, restecg, sex)
# (chol _|_ thalach | trestbps, age, exang, fbs, heartdisease, sex, restecg)
# (chol _|_ trestbps | thalach, age, exang, fbs, heartdisease, sex, restecg)

# %% [markdown]
# # 7.2.3.Inferencing with Bayesian Network

# %%
# Doing exact inference using Variable Elimination
from pgmpy.inference import VariableElimination
HeartDisease_infer = VariableElimination(model)

# Computing the probability of bronc given smoke.
q = HeartDisease_infer.query(variables=['heartdisease'], evidence={'age': 28})
print(q['heartdisease'])
# Out:
# ╒════════════════╤═════════════════════╕
# │ heartdisease   │   phi(heartdisease) │
# ╞════════════════╪═════════════════════╡
# │ heartdisease_0 │              0.6333 │
# ├────────────────┼─────────────────────┤
# │ heartdisease_1 │              0.3667 │
# ╘════════════════╧═════════════════════╛

# %%
q = HeartDisease_infer.query(variables=['heartdisease'], evidence={'chol': 100})
print(q['heartdisease'])
# Out:
# ╒════════════════╤═════════════════════╕
# │ heartdisease   │   phi(heartdisease) │
# ╞════════════════╪═════════════════════╡
# │ heartdisease_0 │              1.0000 │
# ├────────────────┼─────────────────────┤
# │ heartdisease_1 │              0.0000 │
# ╘════════════════╧═════════════════════╛
